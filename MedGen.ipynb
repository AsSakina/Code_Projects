# %% [markdown]
# <a href="https://colab.research.google.com/github/AsSakina/Code_Projects/blob/main/MedGen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MedGen**

# %% [markdown]
# ## **Generate Random Data**

# %%
# Import libraries

import json
import os
import random
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %% [markdown]
# ### **Generate Date**

# %%
# Generate random date within range
def random_date(start, end):
    delta = end - start
    int_delta = (delta.days * 24 * 60 * 60) + delta.seconds
    random_second = random.randrange(int_delta)
    return start + timedelta(seconds=random_second)

# %%
#test
random_date(datetime.strptime('1/1/2020 1:30 PM', '%m/%d/%Y %I:%M %p'), datetime.strptime('1/1/2021 4:50 AM', '%m/%d/%Y %I:%M %p'))
# Out:
# datetime.datetime(2020, 6, 24, 4, 57, 14)

# %%
# Format date to YYYY-MM-DD
def format_date(date):
    return date.strftime('%Y-%m-%d')

# format_date(date)

# %% [markdown]
# ### **Generate patient data**
#
# Génère **1000 patients** avec les éléments suivants :
#
# - age, gender, department, treatment, etc.
#
# - admissionDate : date d’admission (aléatoire sur les 90 derniers jours).
#
# - dischargeDate : nulle si le patient est toujours hospitalisé.
#
# - stayDuration : soit la durée réelle, soit la durée depuis l’admission.
#
# - outcome : s'il est sorti, résultat de traitement pondéré (60% rétabli…).
#
# - treatmentCost : calcul basé sur un coût de base (département + traitement).
#
# - insuranceCovered : % aléatoire de couverture (entre 70% et 95% environ).
#
# Le **coût total** du traitement dépend de :
#
# - Le département (coût de base)
#
# - Le type de traitement (ajoute des surcoûts pour chirurgie ou soins intensifs)
#
# - La durée du séjour

# %%
# Generate patient data
def generate_patient_data(days=90):
    patients = []
    now = datetime.now()
    departments = ['Cardiology', 'Neurology', 'Oncology', 'Pediatrics', 'Emergency', 'Surgery']
    treatments = ['Medication', 'Surgery', 'Therapy', 'Observation', 'Intensive Care']
    outcomes = ['Recovered', 'Improved', 'Stable', 'Deteriorated', 'Deceased']
    outcome_weights = [0.6, 0.2, 0.1, 0.07, 0.03]  # Probability weights

    for i in range(1000):
        admission_date = random_date(now - timedelta(days=days), now)
        stay_duration = random.randint(1, 30)
        discharge_date = admission_date + timedelta(days=stay_duration)

        # Determine if patient is still admitted
        is_admitted = discharge_date > now

        department = random.choice(departments)
        treatment = random.choice(treatments)

        # Weighted random outcome selection
        if is_admitted:
            outcome = 'In Treatment'
        else:
            outcome = random.choices(outcomes, weights=outcome_weights)[0]

        # Generate costs based on department and treatment
        base_cost = {
            'Cardiology': 1500,
            'Neurology': 1800,
            'Oncology': 2200,
            'Pediatrics': 1000,
            'Emergency': 2000,
            'Surgery': 3000
        }.get(department, 1200)

        if treatment == 'Surgery':
            base_cost += 5000
        if treatment == 'Intensive Care':
            base_cost += 3000

        treatment_cost = base_cost * (0.8 + random.random() * 0.4) * stay_duration

        patients.append({
            'patientId': f'P{1000 + i}',
            'age': random.randint(1, 95),
            'gender': random.choice(['Male', 'Female']),
            'department': department,
            'admissionDate': format_date(admission_date),
            'dischargeDate': None if is_admitted else format_date(discharge_date),
            'stayDuration': (now - admission_date).days if is_admitted else stay_duration,
            'treatment': treatment,
            'outcome': outcome,
            'treatmentCost': round(treatment_cost),
            'insuranceCovered': round(treatment_cost * (0.7 + random.random() * 0.25)),
            'isAdmitted': is_admitted
        })

    return patients

# %%
patient_data = generate_patient_data()
pd.DataFrame(patient_data)
# Out:
#     patientId  age  gender  department admissionDate dischargeDate  \
# 0       P1000   24    Male  Cardiology    2025-05-08    2025-05-20
# 1       P1001   47  Female   Emergency    2025-07-07    2025-07-13
# 2       P1002   21  Female   Neurology    2025-04-27    2025-05-11
# 3       P1003   93    Male  Pediatrics    2025-05-31    2025-06-14
# 4       P1004   70    Male  Pediatrics    2025-06-22    2025-06-26
# ..        ...  ...     ...         ...           ...           ...
# 995     P1995   78  Female    Oncology    2025-06-18    2025-06-23
# 996     P1996   53    Male  Cardiology    2025-04-29    2025-05-14
# 997     P1997   80  Female  Pediatrics    2025-05-15    2025-05-22
# 998     P1998   18    Male   Emergency    2025-05-06    2025-06-03
# 999     P1999   23  Female  Cardiology    2025-06-09    2025-07-09
#
#      stayDuration       treatment       outcome  treatmentCost  \
# 0              12      Medication     Recovered          16338
# 1               6     Observation      Improved          11365
# 2              14         Surgery     Recovered          98573
# 3              14     Observation      Improved          12892
# 4               4         Surgery        Stable          26001
# ..            ...             ...           ...            ...
# 995             5         Therapy  Deteriorated          13175
# 996            15  Intensive Care     Recovered          77176
# 997             7         Therapy     Recovered           7504
# 998            28  Intensive Care     Recovered         114590
# 999            30         Therapy      Improved          49437
#
#      insuranceCovered  isAdmitted
# 0               14789       False
# 1                9534       False
# 2               86644       False
# 3               11894       False
# 4               21528       False
# ..                ...         ...
# 995              9938       False
# 996             61686       False
# 997              5779       False
# 998            108261       False
# 999             35935       False
#
# [1000 rows x 12 columns]

# %% [markdown]
# ### **Generate Staff Data**
#
# Crée **200 membres** du personnel :
#
# - role : Docteur, infirmier, technicien, etc.
#
# - salary : dépend du rôle, du département, et de l’ancienneté (yearsOfService)
#
# - performanceScore : score entre 0.70 et 1.00.
#
# - patientsHandled : uniquement pour les rôles médicaux (doctor, nurse, etc.).
#
# Le salaire est ajusté selon :
#
# - Un coefficient pour les départements comme Chirurgie ou Cardiologie (x1.2)
#
# - Une augmentation de 2% par année d’ancienneté

# %%
# Generate staff data
def generate_staff_data():
    departments = ['Cardiology', 'Neurology', 'Oncology', 'Pediatrics', 'Emergency', 'Surgery', 'Administration']
    roles = ['Doctor', 'Nurse', 'Technician', 'Administrative', 'Support']
    staff = []

    for i in range(200):
        department = random.choice(departments)
        role = random.choice(roles)

        # Base salary by role
        base_salary = {
            'Doctor': 120000,
            'Nurse': 70000,
            'Technician': 60000,
            'Administrative': 50000,
            'Support': 40000
        }.get(role, 45000)

        # Adjust by department
        if department in ['Surgery', 'Cardiology']:
            base_salary *= 1.2

        years_of_service = random.randint(0, 30)
        # Salary increases with years of service
        salary = round(base_salary * (1 + years_of_service * 0.02))

        staff.append({
            'staffId': f'S{1000 + i}',
            'department': department,
            'role': role,
            'yearsOfService': years_of_service,
            'salary': salary,
            'patientsHandled': random.randint(10, 100) if role in ['Doctor', 'Nurse'] else 0,
            'performanceScore': round(random.uniform(70, 100) / 100, 2)
        })

    return staff

# %%
staff_data = generate_staff_data()
pd.DataFrame(staff_data)
# Out:
#     staffId      department            role  yearsOfService  salary  \
# 0     S1000       Emergency  Administrative               2   52000
# 1     S1001      Pediatrics         Support               8   46400
# 2     S1002      Cardiology          Doctor              16  190080
# 3     S1003      Cardiology           Nurse               1   85680
# 4     S1004         Surgery  Administrative              18   81600
# ..      ...             ...             ...             ...     ...
# 195   S1195  Administration         Support              17   53600
# 196   S1196         Surgery  Administrative               4   64800
# 197   S1197         Surgery           Nurse               8   97440
# 198   S1198        Oncology      Technician              30   96000
# 199   S1199  Administration  Administrative              19   69000
#
#      patientsHandled  performanceScore
# 0                  0              0.86
# 1                  0              0.84
# 2                 68              0.87
# 3                 53              0.81
# 4                  0              0.98
# ..               ...               ...
# 195                0              0.77
# 196                0              0.79
# 197               17              0.73
# 198                0              0.86
# 199                0              0.88
#
# [200 rows x 7 columns]

# %% [markdown]
# ### **Generate Departement Data**
#
# Pour chaque département (**6 au total**) :
#
# - Patients : combien, durée moyenne de séjour, taux de guérison
#
# - Finances : revenu total (somme des coûts de traitement), salaires totaux, coût d’exploitation
#
# - Ressources : lits disponibles, lits occupés (bed utilization), nombre de staff
#
# - Performance médicale : taux de guérison (patients sortis guéris ou améliorés)

# %%
# Generate department performance data
def generate_department_data(patient_data, staff_data):
    departments = ['Cardiology', 'Neurology', 'Oncology', 'Pediatrics', 'Emergency', 'Surgery']
    department_data = []

    for dept in departments:
        dept_patients = [p for p in patient_data if p['department'] == dept]
        dept_staff = [s for s in staff_data if s['department'] == dept]

        total_patients = len(dept_patients)
        if total_patients > 0:
            avg_stay_duration = sum(p['stayDuration'] for p in dept_patients) / total_patients
        else:
            avg_stay_duration = 0

        total_revenue = sum(p['treatmentCost'] for p in dept_patients)
        total_salaries = sum(s['salary'] for s in dept_staff)

        # Calculate recovery rate
        non_admitted = [p for p in dept_patients if not p['isAdmitted']]
        recovered_patients = len([p for p in non_admitted if p['outcome'] in ['Recovered', 'Improved']])
        recovery_rate = recovered_patients / len(non_admitted) if len(non_admitted) > 0 else 0

        # Calculate bed utilization
        beds_available = {
            'Cardiology': 50,
            'Neurology': 40,
            'Oncology': 60,
            'Pediatrics': 45,
            'Emergency': 30,
            'Surgery': 35
        }[dept]

        currently_admitted = len([p for p in dept_patients if p['isAdmitted']])
        bed_utilization = currently_admitted / beds_available

        department_data.append({
            'department': dept,
            'totalPatients': total_patients,
            'avgStayDuration': round(avg_stay_duration, 2),
            'totalRevenue': total_revenue,
            'totalSalaries': total_salaries,
            'operatingCost': total_salaries + random.randint(50000, 200000),  # Add other costs
            'recoveryRate': round(recovery_rate, 2),
            'bedsAvailable': beds_available,
            'currentlyAdmitted': currently_admitted,
            'bedUtilization': round(bed_utilization, 2),
            'staffCount': len(dept_staff),
            'doctorCount': len([s for s in dept_staff if s['role'] == 'Doctor']),
            'nurseCount': len([s for s in dept_staff if s['role'] == 'Nurse'])
        })

    return department_data

# %%
department_data = generate_department_data(patient_data, staff_data)
pd.DataFrame(department_data)
# Out:
#    department  totalPatients  avgStayDuration  totalRevenue  totalSalaries  \
# 0  Cardiology            178            13.97       8235256        2515440
# 1   Neurology            159            13.95       7945112        2749600
# 2    Oncology            153            13.27       8931964        2679400
# 3  Pediatrics            184            13.76       7166373        2313800
# 4   Emergency            157            14.34       9655686        2413800
# 5     Surgery            169            13.38      12042518        2849760
#
#    operatingCost  recoveryRate  bedsAvailable  currentlyAdmitted  \
# 0        2572241          0.75             50                 27
# 1        2822894          0.81             40                 23
# 2        2816209          0.86             60                 28
# 3        2425415          0.83             45                 31
# 4        2526128          0.76             30                 22
# 5        2975856          0.80             35                 26
#
#    bedUtilization  staffCount  doctorCount  nurseCount
# 0            0.54          23            5           3
# 1            0.57          27            8           6
# 2            0.47          33            5           7
# 3            0.69          25            6           6
# 4            0.73          27            8           2
# 5            0.74          30            4           6

# %% [markdown]
# ### **Generate Daily Metrics**
#
# Génère des données aléatoires pour 90 jours :
#
# - newAdmissions, discharges, emergencyVisits, surgeries, revenue, expenses
#
# Cela permet d’**analyser l’activité jour par jour** sous forme de **séries temporelles**.

# %%
# Generate daily metrics for time series
def generate_daily_metrics(days=90):
    daily_metrics = []
    now = datetime.now()

    for i in range(days):
        date = now - timedelta(days=days-i)

        daily_metrics.append({
            'date': format_date(date),
            'newAdmissions': random.randint(5, 25),
            'discharges': random.randint(5, 20),
            'emergencyVisits': random.randint(20, 60),
            'surgeries': random.randint(3, 15),
            'revenue': random.randint(50000, 150000),
            'expenses': random.randint(40000, 120000)
        })

    return daily_metrics

# %%
daily_metrics_data = generate_daily_metrics()
pd.DataFrame(daily_metrics_data)
# Out:
#           date  newAdmissions  discharges  emergencyVisits  surgeries  \
# 0   2025-04-22             12           9               30         13
# 1   2025-04-23             11           5               22          7
# 2   2025-04-24             18           6               27         10
# 3   2025-04-25             16          16               58         13
# 4   2025-04-26             14          17               37          9
# ..         ...            ...         ...              ...        ...
# 85  2025-07-16             25          15               46         12
# 86  2025-07-17             21           6               31          7
# 87  2025-07-18              7          11               43          9
# 88  2025-07-19             11           6               60          3
# 89  2025-07-20             20          20               37         13
#
#     revenue  expenses
# 0     92518     48396
# 1    122451     84726
# 2    110933     40894
# 3     72155     48917
# 4    116736     71829
# ..      ...       ...
# 85   119776     80427
# 86    97122     48675
# 87   115615    114655
# 88   131926     76333
# 89   140627     74339
#
# [90 rows x 7 columns]

# %% [markdown]
# ### **Generate all data (Skip it)**
#
# This part will generate all data and save it to JSON files.
#
# - Appelle les 4 fonctions ci-dessus
#
# - Crée un dossier ./data si nécessaire
#
# - Sauvegarde chaque jeu de données dans un fichier .json
#
#   - patients.json
#
#   - staff.json
#
#   - departments.json
#
#   - daily_metrics.json
#
# - Affiche un résumé du nombre d'enregistrements générés

# %%
# Generate all data and save to JSON files
def generate_all_data():
    patient_data = generate_patient_data()
    staff_data = generate_staff_data()
    department_data = generate_department_data(patient_data, staff_data)
    daily_metrics = generate_daily_metrics()

    # Create data directory if it doesn't exist
    if not os.path.exists('./data'):
        os.makedirs('./data')

    with open('./data/patients.json', 'w') as f:
        json.dump(patient_data, f, indent=2)

    with open('./data/staff.json', 'w') as f:
        json.dump(staff_data, f, indent=2)

    with open('./data/departments.json', 'w') as f:
        json.dump(department_data, f, indent=2)

    with open('./data/daily_metrics.json', 'w') as f:
        json.dump(daily_metrics, f, indent=2)

    print('Generated fictive health structure data:')
    print(f'- {len(patient_data)} patient records')
    print(f'- {len(staff_data)} staff records')
    print(f'- {len(department_data)} department performance records')
    print(f'- {len(daily_metrics)} days of daily metrics')
    print('Data saved to ./data/ directory')

# %% [markdown]
# ### **Exécution**
#
# Cela permet d’exécuter le script uniquement lorsqu'il est lancé directement (et non importé comme module).

# %%
if __name__ == "__main__":
    generate_all_data()
# Out:
# Generated fictive health structure data:
# - 1000 patient records
# - 200 staff records
# - 6 department performance records
# - 90 days of daily metrics
# Data saved to ./data/ directory

# %% [markdown]
# ## **Data Pre-processing**

# %% [markdown]
# ### **Load Data**

# %%
# Load Patients data

patient_data = pd.read_json('./data/patients.json')

# %%
# Load Staff data

staff_data = pd.read_json('./data/staff.json')

# %%
# Load Departments data

department_data = pd.read_json('./data/departments.json')

# %%
# Load Daily metrics data

metrics_data = pd.read_json('./data/daily_metrics.json')

# %% [markdown]
# ### **Display datasets**

# %%
# Patients Data

patient_data.head()
# Out:
#   patientId  age  gender  department admissionDate dischargeDate  \
# 0     P1000   50    Male  Cardiology    2025-05-29    2025-06-20
# 1     P1001   20    Male   Emergency    2025-05-03    2025-05-05
# 2     P1002   67  Female  Cardiology    2025-06-20    2025-07-16
# 3     P1003   37    Male   Neurology    2025-05-28    2025-06-24
# 4     P1004   47  Female     Surgery    2025-06-04    2025-07-03
#
#    stayDuration       treatment       outcome  treatmentCost  \
# 0            22     Observation     Recovered          31607
# 1             2         Therapy      Deceased           3985
# 2            26  Intensive Care  Deteriorated          96399
# 3            27  Intensive Care      Improved         136722
# 4            29  Intensive Care     Recovered         148673
#
#    insuranceCovered  isAdmitted
# 0             29709       False
# 1              3056       False
# 2             90888       False
# 3             98642       False
# 4            137675       False

# %%
# Staff Data

staff_data.head()
# Out:
#   staffId department            role  yearsOfService  salary  patientsHandled  \
# 0   S1000  Emergency           Nurse              17   93800               79
# 1   S1001    Surgery           Nurse              29  132720               46
# 2   S1002    Surgery  Administrative              27   92400                0
# 3   S1003    Surgery  Administrative              18   81600                0
# 4   S1004    Surgery           Nurse              30  134400               44
#
#    performanceScore
# 0              0.82
# 1              0.81
# 2              0.91
# 3              0.88
# 4              0.96

# %%
# Department Data

department_data.head()
# Out:
#    department  totalPatients  avgStayDuration  totalRevenue  totalSalaries  \
# 0  Cardiology            161            13.20       7985903        2611440
# 1   Neurology            168            14.65       9111593        2556000
# 2    Oncology            168            13.49       9909357        3603200
# 3  Pediatrics            177            13.01       7541597        3002000
# 4   Emergency            170            14.53       9767089        2680200
#
#    operatingCost  recoveryRate  bedsAvailable  currentlyAdmitted  \
# 0        2798682          0.80             50                 28
# 1        2741313          0.84             40                 40
# 2        3789201          0.84             60                 26
# 3        3059114          0.79             45                 37
# 4        2739548          0.76             30                 27
#
#    bedUtilization  staffCount  doctorCount  nurseCount
# 0            0.56          27            3           5
# 1            1.00          26            7           9
# 2            0.43          36           11          10
# 3            0.82          32            7           8
# 4            0.90          28            8           4

# %%
# Daily Metrics Data

metrics_data.head()
# Out:
#         date  newAdmissions  discharges  emergencyVisits  surgeries  revenue  \
# 0 2025-04-22             22           8               60         13   120038
# 1 2025-04-23             23           8               34         13   106975
# 2 2025-04-24              6           9               58          9   134386
# 3 2025-04-25             17           5               38         12   112336
# 4 2025-04-26             15          17               29         15    70154
#
#    expenses
# 0     77681
# 1     65743
# 2     68412
# 3     54216
# 4    112666

# %% [markdown]
# ### **Data Explorer**

# %%
# Data Explorer

def explore_info(data):
  print("\n--- Infos sur le DataFrame ---")
  print("====================================")
  print("     ")
  print("     ")
  data.info()

def describe_data(data):
  print("\n--- Statistiques descriptives ---")
  print("====================================")
  print("     ")
  print("     ")

  print(data.describe(include='all'))

def unique_values(data):
  print("\n--- Valeurs uniques par colonne ---")
  print("====================================")
  print("     ")
  print("     ")
  for col in data.columns:
    print(f"{col} : {data[col].nunique()} valeurs uniques")
    print("---------------------------------------")

# %% [markdown]
# #### **Patient**

# %%
# Informations

explore_info(patient_data)
# Out:
# --- Infos sur le DataFrame ---
# ====================================
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   patientId         1000 non-null   object
#  1   age               1000 non-null   int64
#  2   gender            1000 non-null   object
#  3   department        1000 non-null   object
#  4   admissionDate     1000 non-null   object
#  5   dischargeDate     819 non-null    object
#  6   stayDuration      1000 non-null   int64
#  7   treatment         1000 non-null   object
#  8   outcome           1000 non-null   object
#  9   treatmentCost     1000 non-null   int64
#  10  insuranceCovered  1000 non-null   int64
#  11  isAdmitted        1000 non-null   bool
# dtypes: bool(1), int64(4), object(7)
# memory usage: 87.0+ KB

# %%
# Descriptive Statistics

describe_data(patient_data)
# Out:
# --- Statistiques descriptives ---
# ====================================
#
#
#        patientId          age  gender  department admissionDate dischargeDate  \
# count       1000  1000.000000    1000        1000          1000           819
# unique      1000          NaN       2           6            91            88
# top        P1999          NaN  Female  Pediatrics    2025-06-01    2025-06-29
# freq           1          NaN     520         177            19            20
# mean         NaN    48.751000     NaN         NaN           NaN           NaN
# std          NaN    28.073673     NaN         NaN           NaN           NaN
# min          NaN     1.000000     NaN         NaN           NaN           NaN
# 25%          NaN    24.000000     NaN         NaN           NaN           NaN
# 50%          NaN    49.000000     NaN         NaN           NaN           NaN
# 75%          NaN    73.000000     NaN         NaN           NaN           NaN
# max          NaN    95.000000     NaN         NaN           NaN           NaN
#
#         stayDuration   treatment    outcome  treatmentCost  insuranceCovered  \
# count    1000.000000        1000       1000    1000.000000       1000.000000
# unique           NaN           5          6            NaN               NaN
# top              NaN  Medication  Recovered            NaN               NaN
# freq             NaN         218        508            NaN               NaN
# mean       13.677000         NaN        NaN   54789.179000      45621.054000
# std         8.534372         NaN        NaN   48075.745767      41141.857556
# min         0.000000         NaN        NaN     992.000000        744.000000
# 25%         6.750000         NaN        NaN   18989.000000      15659.750000
# 50%        13.000000         NaN        NaN   39224.500000      32455.000000
# 75%        20.000000         NaN        NaN   77869.750000      63925.000000
# max        30.000000         NaN        NaN  258087.000000     236345.000000
#
#        isAdmitted
# count        1000
# unique          2
# top         False
# freq          819
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
# Explore Unique values

unique_values(patient_data)
# Out:
# --- Valeurs uniques par colonne ---
# ====================================
#
#
# patientId : 1000 valeurs uniques
# ---------------------------------------
# age : 95 valeurs uniques
# ---------------------------------------
# gender : 2 valeurs uniques
# ---------------------------------------
# department : 6 valeurs uniques
# ---------------------------------------
# admissionDate : 91 valeurs uniques
# ---------------------------------------
# dischargeDate : 88 valeurs uniques
# ---------------------------------------
# stayDuration : 31 valeurs uniques
# ---------------------------------------
# treatment : 5 valeurs uniques
# ---------------------------------------
# outcome : 6 valeurs uniques
# ---------------------------------------
# treatmentCost : 995 valeurs uniques
# ---------------------------------------
# insuranceCovered : 991 valeurs uniques
# ---------------------------------------
# isAdmitted : 2 valeurs uniques
# ---------------------------------------

# %% [markdown]
# #### **Staff**

# %%
# Informations

explore_info(staff_data)
# Out:
# --- Infos sur le DataFrame ---
# ====================================
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   staffId           200 non-null    object
#  1   department        200 non-null    object
#  2   role              200 non-null    object
#  3   yearsOfService    200 non-null    int64
#  4   salary            200 non-null    int64
#  5   patientsHandled   200 non-null    int64
#  6   performanceScore  200 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 11.1+ KB

# %%
# Descriptive Statistics

describe_data(staff_data)
# Out:
# --- Statistiques descriptives ---
# ====================================
#
#
#        staffId department   role  yearsOfService         salary  \
# count      200        200    200      200.000000     200.000000
# unique     200          7      5             NaN            NaN
# top      S1000   Oncology  Nurse             NaN            NaN
# freq         1         36     45             NaN            NaN
# mean       NaN        NaN    NaN       14.855000   95104.400000
# std        NaN        NaN    NaN        8.945619   41197.301329
# min        NaN        NaN    NaN        0.000000   40800.000000
# 25%        NaN        NaN    NaN        7.000000   64680.000000
# 50%        NaN        NaN    NaN       15.500000   84000.000000
# 75%        NaN        NaN    NaN       22.000000  110080.000000
# max        NaN        NaN    NaN       30.000000  195840.000000
#
#         patientsHandled  performanceScore
# count         200.00000        200.000000
# unique              NaN               NaN
# top                 NaN               NaN
# freq                NaN               NaN
# mean           25.98000          0.856800
# std            34.37145          0.087349
# min             0.00000          0.700000
# 25%             0.00000          0.790000
# 50%             0.00000          0.850000
# 75%            54.50000          0.930000
# max            99.00000          1.000000

# %%
# Explore unique values

unique_values(staff_data)
# Out:
# --- Valeurs uniques par colonne ---
# ====================================
#
#
# staffId : 200 valeurs uniques
# ---------------------------------------
# department : 7 valeurs uniques
# ---------------------------------------
# role : 5 valeurs uniques
# ---------------------------------------
# yearsOfService : 31 valeurs uniques
# ---------------------------------------
# salary : 125 valeurs uniques
# ---------------------------------------
# patientsHandled : 56 valeurs uniques
# ---------------------------------------
# performanceScore : 31 valeurs uniques
# ---------------------------------------

# %% [markdown]
# #### **Departments**

# %%
# Informations

explore_info(department_data)
# Out:
# --- Infos sur le DataFrame ---
# ====================================
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   department         6 non-null      object
#  1   totalPatients      6 non-null      int64
#  2   avgStayDuration    6 non-null      float64
#  3   totalRevenue       6 non-null      int64
#  4   totalSalaries      6 non-null      int64
#  5   operatingCost      6 non-null      int64
#  6   recoveryRate       6 non-null      float64
#  7   bedsAvailable      6 non-null      int64
#  8   currentlyAdmitted  6 non-null      int64
#  9   bedUtilization     6 non-null      float64
#  10  staffCount         6 non-null      int64
#  11  doctorCount        6 non-null      int64
#  12  nurseCount         6 non-null      int64
# dtypes: float64(3), int64(9), object(1)
# memory usage: 756.0+ bytes

# %%
# Descriptive Statistics

describe_data(department_data)
# Out:
# --- Statistiques descriptives ---
# ====================================
#
#
#         department  totalPatients  avgStayDuration  totalRevenue  \
# count            6       6.000000         6.000000  6.000000e+00
# unique           6            NaN              NaN           NaN
# top     Cardiology            NaN              NaN           NaN
# freq             1            NaN              NaN           NaN
# mean           NaN     166.666667        13.671667  9.131530e+06
# std            NaN       7.312090         0.729285  1.153339e+06
# min            NaN     156.000000        13.010000  7.541597e+06
# 25%            NaN     162.750000        13.162500  8.267326e+06
# 50%            NaN     168.000000        13.345000  9.439341e+06
# 75%            NaN     169.500000        14.270000  9.873790e+06
# max            NaN     177.000000        14.650000  1.047364e+07
#
#         totalSalaries  operatingCost  recoveryRate  bedsAvailable  \
# count    6.000000e+00   6.000000e+00      6.000000       6.000000
# unique            NaN            NaN           NaN            NaN
# top               NaN            NaN           NaN            NaN
# freq              NaN            NaN           NaN            NaN
# mean     2.828247e+06   2.950480e+06      0.810000      43.333333
# std      4.173447e+05   4.398888e+05      0.032249      10.801234
# min      2.516640e+06   2.575019e+06      0.760000      30.000000
# 25%      2.569860e+06   2.739989e+06      0.792500      36.250000
# 50%      2.645820e+06   2.769998e+06      0.815000      42.500000
# 75%      2.921550e+06   2.994006e+06      0.837500      48.750000
# max      3.603200e+06   3.789201e+06      0.840000      60.000000
#
#         currentlyAdmitted  bedUtilization  staffCount  doctorCount  nurseCount
# count            6.000000        6.000000    6.000000     6.000000    6.000000
# unique                NaN             NaN         NaN          NaN         NaN
# top                   NaN             NaN         NaN          NaN         NaN
# freq                  NaN             NaN         NaN          NaN         NaN
# mean            30.166667        0.728333   29.333333     6.500000    6.500000
# std              6.735478        0.216187    3.881580     3.082207    2.880972
# min             23.000000        0.430000   26.000000     3.000000    3.000000
# 25%             26.250000        0.585000   27.000000     4.000000    4.250000
# 50%             27.500000        0.740000   27.500000     7.000000    6.500000
# 75%             34.750000        0.880000   31.000000     7.750000    8.750000
# max             40.000000        1.000000   36.000000    11.000000   10.000000

# %%
# Explore unique values

unique_values(department_data)
# Out:
# --- Valeurs uniques par colonne ---
# ====================================
#
#
# department : 6 valeurs uniques
# ---------------------------------------
# totalPatients : 5 valeurs uniques
# ---------------------------------------
# avgStayDuration : 6 valeurs uniques
# ---------------------------------------
# totalRevenue : 6 valeurs uniques
# ---------------------------------------
# totalSalaries : 6 valeurs uniques
# ---------------------------------------
# operatingCost : 6 valeurs uniques
# ---------------------------------------
# recoveryRate : 5 valeurs uniques
# ---------------------------------------
# bedsAvailable : 6 valeurs uniques
# ---------------------------------------
# currentlyAdmitted : 6 valeurs uniques
# ---------------------------------------
# bedUtilization : 6 valeurs uniques
# ---------------------------------------
# staffCount : 5 valeurs uniques
# ---------------------------------------
# doctorCount : 4 valeurs uniques
# ---------------------------------------
# nurseCount : 6 valeurs uniques
# ---------------------------------------

# %% [markdown]
# #### **Daily Metrics**

# %%
# Informations

explore_info(metrics_data)
# Out:
# --- Infos sur le DataFrame ---
# ====================================
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             90 non-null     datetime64[ns]
#  1   newAdmissions    90 non-null     int64
#  2   discharges       90 non-null     int64
#  3   emergencyVisits  90 non-null     int64
#  4   surgeries        90 non-null     int64
#  5   revenue          90 non-null     int64
#  6   expenses         90 non-null     int64
# dtypes: datetime64[ns](1), int64(6)
# memory usage: 5.1 KB

# %%
# Descriptive Statistics

describe_data(metrics_data)
# Out:
# --- Statistiques descriptives ---
# ====================================
#
#
#                       date  newAdmissions  discharges  emergencyVisits  \
# count                   90      90.000000   90.000000        90.000000
# mean   2025-06-05 12:00:00      14.955556   12.277778        38.911111
# min    2025-04-22 00:00:00       5.000000    5.000000        21.000000
# 25%    2025-05-14 06:00:00      10.000000    9.000000        29.250000
# 50%    2025-06-05 12:00:00      15.000000   12.000000        39.000000
# 75%    2025-06-27 18:00:00      20.000000   16.000000        46.000000
# max    2025-07-20 00:00:00      25.000000   20.000000        60.000000
# std                    NaN       5.992338    4.527141        10.812648
#
#        surgeries        revenue       expenses
# count  90.000000      90.000000      90.000000
# mean    8.955556  101363.833333   80222.311111
# min     3.000000   51839.000000   40430.000000
# 25%     6.000000   83454.000000   58272.750000
# 50%     9.000000   98291.000000   82073.500000
# 75%    12.000000  121451.750000   97584.000000
# max    15.000000  148818.000000  118816.000000
# std     3.647105   28023.319055   23430.884289

# %%
# Explore unique values

unique_values(metrics_data)
# Out:
# --- Valeurs uniques par colonne ---
# ====================================
#
#
# date : 90 valeurs uniques
# ---------------------------------------
# newAdmissions : 21 valeurs uniques
# ---------------------------------------
# discharges : 16 valeurs uniques
# ---------------------------------------
# emergencyVisits : 39 valeurs uniques
# ---------------------------------------
# surgeries : 13 valeurs uniques
# ---------------------------------------
# revenue : 90 valeurs uniques
# ---------------------------------------
# expenses : 90 valeurs uniques
# ---------------------------------------

# %% [markdown]
# ### **Checking and Handling : Missing values**

# %%
def missing_values(data):
  print("\n--- Valeurs manquantes par colonne ---")
  print("====================================")
  print("     ")
  print("     ")
  print(data.isnull().sum())

# %%
# Patient Data

missing_values(patient_data)
# Out:
# --- Valeurs manquantes par colonne ---
# ====================================
#
#
# patientId             0
# age                   0
# gender                0
# department            0
# admissionDate         0
# dischargeDate       181
# stayDuration          0
# treatment             0
# outcome               0
# treatmentCost         0
# insuranceCovered      0
# isAdmitted            0
# dtype: int64

# %% [markdown]
# **Reminder** :
#
# ---
#
#
#
# dischargeDate : nulle si le patient est toujours hospitalisé.

# %%
# Staff Data

missing_values(staff_data)
# Out:
# --- Valeurs manquantes par colonne ---
# ====================================
#
#
# staffId             0
# department          0
# role                0
# yearsOfService      0
# salary              0
# patientsHandled     0
# performanceScore    0
# dtype: int64

# %%
# Departement Data

missing_values(department_data)
# Out:
# --- Valeurs manquantes par colonne ---
# ====================================
#
#
# department           0
# totalPatients        0
# avgStayDuration      0
# totalRevenue         0
# totalSalaries        0
# operatingCost        0
# recoveryRate         0
# bedsAvailable        0
# currentlyAdmitted    0
# bedUtilization       0
# staffCount           0
# doctorCount          0
# nurseCount           0
# dtype: int64

# %%
# Daily Metrics

missing_values(metrics_data)
# Out:
# --- Valeurs manquantes par colonne ---
# ====================================
#
#
# date               0
# newAdmissions      0
# discharges         0
# emergencyVisits    0
# surgeries          0
# revenue            0
# expenses           0
# dtype: int64

# %% [markdown]
# ### **Checking and Handling :Outliers Handling**
#
# - Check outliers
# - Check Distribution
# - Handle Outliers

# %%
import plotly.express as px

# %%
for col in patient_data.columns:
  if patient_data[col].dtype != "object" :
    if patient_data[col].dtype != "bool":
      print(f"Column {patient_data[col].name} : {patient_data[col].dtype}")
# Out:
# Column age : int64
# Column stayDuration : int64
# Column treatmentCost : int64
# Column insuranceCovered : int64

# %%
def check_outliers(data, columns):
  for col in columns:
    if data[col].dtype != "object" :
      if data[col].dtype != "bool":
        Q1 = data[col].quantile(0.25)
        Q3 = data[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers
ATA")
print("====================================")
print("     ")
print("     ")
check_outliers(staff_data, staff_data.columns)
# Out:
#
#
# ====================================
# STAFF DATA
# ====================================
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5f0da920-3f52-4e78-88ac-498e3d3aa7ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f0da920-3f52-4e78-88ac-498e3d3aa7ab")) {                    Plotly.newPlot(                        "5f0da920-3f52-4e78-88ac-498e3d3aa7ab",                        [{"alignmentgroup":"True","hovertemplate":"yearsOfService=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[17,29,27,18,30,15,27,10,7,18,1,3,2,10,25,2,3,11,22,23,19,7,15,16,29,26,18,3,3,22,16,19,8,16,0,6,8,6,15,8,24,19,19,10,30,24,21,14,0,6,14,9,20,9,20,8,10,28,14,19,25,8,23,25,14,4,19,2,6,19,1,8,30,25,15,6,10,5,17,24,8,18,25,22,11,18,8,11,26,7,1,0,15,5,2,24,21,4,20,14,27,24,9,7,4,16,18,11,17,16,22,30,17,0,29,2,6,30,26,24,0,11,26,20,13,3,6,26,16,13,0,0,22,15,3,18,20,10,27,4,22,22,27,23,6,3,18,29,8,6,14,13,21,1,21,23,4,25,26,23,27,5,11,5,2,13,23,5,19,26,1,27,21,4,28,1,22,24,17,12,30,9,30,9,2,30,22,20,22,10,29,14,2,11,17,8,20,12,18,16],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parc ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="990dffd1-1b7f-4e84-b081-8e50713cd14d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("990dffd1-1b7f-4e84-b081-8e50713cd14d")) {                    Plotly.newPlot(                        "990dffd1-1b7f-4e84-b081-8e50713cd14d",                        [{"alignmentgroup":"True","hovertemplate":"salary=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[93800,132720,92400,81600,134400,91000,184800,172800,68400,81600,48960,42400,72800,84000,75000,62400,42400,48800,86400,122640,69000,68400,52000,190080,94800,60800,163200,127200,63600,172800,79200,96600,81200,158400,120000,67200,81200,134400,156000,58000,103600,66240,55200,86400,96000,88800,170400,51200,120000,53760,76800,70800,84000,59000,98000,167040,60000,112320,76800,55200,75000,58000,175200,105000,153600,51840,165600,41600,78400,165600,85680,167040,112000,75000,91000,67200,48000,44000,53600,103600,139200,95200,105000,57600,48800,81600,81200,87840,72960,82080,73440,84000,65000,52800,74880,88800,102240,64800,98000,51200,107800,88800,82600,79800,75600,158400,195840,48800,93800,95040,86400,96000,64320,50000,94800,41600,78400,192000,91200,88800,60000,146400,182400,168000,88200,74200,53760,109440,52800,151200,60000,70000,57600,187200,74200,81600,168000,144000,92400,51840,172800,100800,184800,105120,78400,89040,95200,189600,81200,94080,92160,151200,85200,71400,56800,87600,54000,75000,91200,102200,77000,77000,61000,55000,124800,151200,58400,77000,165600,182400,40800,61600,85200,64800,187200,51000,86400,177600,67000,62000,96000,70800,192000,47200,49920,115200,69120,168000,57600,144000,132720,76800,62400,85400,96480,46400,70000,148800,54400,95040],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333," ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cdecc70b-b7a5-4d91-8da7-20490b8ac744" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cdecc70b-b7a5-4d91-8da7-20490b8ac744")) {                    Plotly.newPlot(                        "cdecc70b-b7a5-4d91-8da7-20490b8ac744",                        [{"alignmentgroup":"True","hovertemplate":"patientsHandled=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":
ATA")
print("====================================")
print("     ")
print("     ")
check_outliers(department_data, department_data.columns)
# Out:
#
#
# ====================================
# DEPARTMENTS DATA
# ====================================
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b010a0d4-0e82-4bb5-b8ea-1800cad9647d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b010a0d4-0e82-4bb5-b8ea-1800cad9647d")) {                    Plotly.newPlot(                        "b010a0d4-0e82-4bb5-b8ea-1800cad9647d",                        [{"alignmentgroup":"True","hovertemplate":"totalPatients=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[161,168,168,177,170,156],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"col ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="04efade4-5229-4c56-9eb2-b8c51e1a5c0d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04efade4-5229-4c56-9eb2-b8c51e1a5c0d")) {                    Plotly.newPlot(                        "04efade4-5229-4c56-9eb2-b8c51e1a5c0d",                        [{"alignmentgroup":"True","hovertemplate":"avgStayDuration=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[13.2,14.65,13.49,13.01,14.53,13.15],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar"," ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c1ee3cc7-1a04-47ce-a12e-04a17d5d46aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c1ee3cc7-1a04-47ce-a12e-04a17d5d46aa")) {                    Plotly.newPlot(                        "c1ee3cc7-1a04-47ce-a12e-04a17d5d46aa",                        [{"alignmentgroup":"True","hovertemplate":"totalRevenue=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[7985903,9111593,9909357,7541597,9767089,10473640],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scat ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="058a41fa-9ec0-403c-8688-dacff0b0b42c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("058a41fa-9ec0-403c-8688-dacff0b0b42c")) {                    Plotly.newPlot(                        "058a41fa-9ec0-403c-8688-dacff0b0b42c",                        [{"alignmentgroup":"True","hovertemplate":"totalSalaries=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[2611440,2556000,3603200,3002000,2680200,2516640],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scat ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8110dbb6-7e97-4c78-8f06-3d5bce9fd5e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8110dbb6-7e97-4c78-8f06-3d5bce9fd5e8")) {                    Plotly.newPlot(                        "8110dbb6-7e97-4c78-8f06-3d5bce9fd5e8",                        [{"alignmentgroup":"True","hovertemplate":"operatingCost=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[2798682,2741313,3789201,3059114,2739548,2575019],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scat ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4f5ac30a-db19-4f8b-89d3-8afe53a404f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f5ac30a-db19-4f8b-89d3-8afe53a404f7")) {                    Plotly.newPlot(                        "4f5ac30a-db19-4f8b-89d3-8afe53a404f7",                        [{"alignmentgroup":"True","hovertemplate":"recoveryRate=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[0.8,0.84,0.84,0.79,0.76,0.8300000000000001],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpol ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bcc0e8ac-4058-4a43-935b-4044975feea2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bcc0e8ac-4058-4a43-935b-4044975feea2")) {                    Plotly.newPlot(                        "bcc0e8ac-4058-4a43-935b-4044975feea2",                        [{"alignmentgroup":"True","hovertemplate":"bedsAvailable=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[50,40,60,45,30,35],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="61dad22a-8a1f-4646-ae40-02157a8bf90f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61dad22a-8a1f-4646-ae40-02157a8bf90f")) {                    Plotly.newPlot(                        "61dad22a-8a1f-4646-ae40-02157a8bf90f",                        [{"alignmentgroup":"True","hovertemplate":"currentlyAdmitted=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[28,40,26,37,27,23],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"color ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fcc81d11-a778-4ec5-8e45-cfb0bdd563fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fcc81d11-a778-4ec5-8e45-cfb0bdd563fb")) {                    Plotly.newPlot(                        "fcc81d11-a778-4ec5-8e45-cfb0bdd563fb",                        [{"alignmentgroup":"True","hovertemplate":"bedUtilization=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[0.56,1.0,0.43,0.8200000000000001,0.9,0.66],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpo ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f6c4db0b-f9dd-4b7f-b346-45de2d41d5cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6c4db0b-f9dd-4b7f-b346-45de2d41d5cf")) {                    Plotly.newPlot(                        "f6c4db0b-f9dd-4b7f-b346-45de2d41d5cf",                        [{"alignmentgroup":"True","hovertemplate":"staffCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[27,26,36,32,28,27],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ac3cad07-6938-4e9d-a4a4-d26f35315c44" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac3cad07-6938-4e9d-a4a4-d26f35315c44")) {                    Plotly.newPlot(                        "ac3cad07-6938-4e9d-a4a4-d26f35315c44",                        [{"alignmentgroup":"True","hovertemplate":"doctorCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[3,7,11,7,8,3],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outl ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f6bc60f5-3a47-4912-aef6-e31e502ae2a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6bc60f5-3a47-4912-aef6-e31e502ae2a4")) {                    Plotly.newPlot(                        "f6bc60f5-3a47-4912-aef6-e31e502ae2a4",                        [{"alignmentgroup":"True","hovertemplate":"nurseCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[5,9,10,8,4,3],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outli ...

# %%
# Daily Metrics data

print("     ")
print("     ")
print("====================================")
print("DAILY METRICS DATA")
print("====================================")
print("     ")
print("     ")
check_outliers(metrics_data, metrics_data.columns)
# Out:
#
#
# ====================================
# DAILY METRICS DATA
# ====================================
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d0aa657c-fe76-498a-8f5d-eb17fce51b2c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0aa657c-fe76-498a-8f5d-eb17fce51b2c")) {                    Plotly.newPlot(                        "d0aa657c-fe76-498a-8f5d-eb17fce51b2c",                        [{"alignmentgroup":"True","hovertemplate":"date=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":["2025-04-22T00:00:00","2025-04-23T00:00:00","2025-04-24T00:00:00","2025-04-25T00:00:00","2025-04-26T00:00:00","2025-04-27T00:00:00","2025-04-28T00:00:00","2025-04-29T00:00:00","2025-04-30T00:00:00","2025-05-01T00:00:00","2025-05-02T00:00:00","2025-05-03T00:00:00","2025-05-04T00:00:00","2025-05-05T00:00:00","2025-05-06T00:00:00","2025-05-07T00:00:00","2025-05-08T00:00:00","2025-05-09T00:00:00","2025-05-10T00:00:00","2025-05-11T00:00:00","2025-05-12T00:00:00","2025-05-13T00:00:00","2025-05-14T00:00:00","2025-05-15T00:00:00","2025-05-16T00:00:00","2025-05-17T00:00:00","2025-05-18T00:00:00","2025-05-19T00:00:00","2025-05-20T00:00:00","2025-05-21T00:00:00","2025-05-22T00:00:00","2025-05-23T00:00:00","2025-05-24T00:00:00","2025-05-25T00:00:00","2025-05-26T00:00:00","2025-05-27T00:00:00","2025-05-28T00:00:00","2025-05-29T00:00:00","2025-05-30T00:00:00","2025-05-31T00:00:00","2025-06-01T00:00:00","2025-06-02T00:00:00","2025-06-03T00:00:00","2025-06-04T00:00:00","2025-06-05T00:00:00","2025-06-06T00:00:00","2025-06-07T00:00:00","2025-06-08T00:00:00","2025-06-09T00:00:00","2025-06-10T00:00:00","2025-06-11T00:00:00","2025-06-12T00:00:00","2025-06-13T00:00:00","2025-06-14T00:00:00","2025-06-15T00:00:00","2025-06-16T00:00:00","2025-06-17T00:00:00","2025-06-18T00:00:00","2025-06-19T00:00:00","2025-06-20T00:00:00","2025-06-21T00:00:00","2025-06-22T00:00:00","2025-06-23T00:00:00","2025-06-24T00:00:00","2025-06-25T00:00:00","2025-06-26T00:00:00","2025-06-27T00:00:00","2025-06-28T00:00:00","2025-06-29T00:00:00","2025-06-30T00:00:00","2025-07-01T00:00:00","2025-07-02T00:00:00","2025-07-03T00:00:00","2025-07-04T00:00:00","2025-07-05T00:00:00","2025-07-06T00:00:00","2025-07-07T00:00:00","2025-07-08T00:00:00","2025-07-09T00:00:00","2025-07-10T00:00:00","2025-07-11T00:00:00","2025-07-12T00:00:00","2025-07-13T00:00:00","2025-07-14T00:00:00","2025-07-15T00:00:00","2025-07-16T00:00:00","2025-07-17T00:00:00","2025-07-18T00:00:00","2025-07-19T00:00:00","2025-07-20T00:00:00"],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[ ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d78866c5-1704-4af4-9365-8d80d08156e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d78866c5-1704-4af4-9365-8d80d08156e3")) {                    Plotly.newPlot(                        "d78866c5-1704-4af4-9365-8d80d08156e3",                        [{"alignmentgroup":"True","hovertemplate":"newAdmissions=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[22,23,6,17,15,14,13,19,20,15,14,6,13,19,5,16,25,21,8,18,8,24,10,23,17,25,8,24,21,5,16,8,23,15,10,17,21,23,14,23,10,20,8,5,21,10,23,12,10,8,16,17,19,9,18,23,12,15,5,19,14,7,6,21,25,16,14,17,6,19,12,9,14,16,18,5,14,11,23,8,15,10,16,9,20,25,22,7,11,12],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","wid ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="25b0ae2c-0986-4bc6-9121-39768481d88f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25b0ae2c-0986-4bc6-9121-39768481d88f")) {                    Plotly.newPlot(                        "25b0ae2c-0986-4bc6-9121-39768481d88f",                        [{"alignmentgroup":"True","hovertemplate":"discharges=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[8,8,9,5,17,13,12,17,12,15,10,10,6,10,11,15,10,5,18,14,15,19,16,5,5,7,20,20,17,18,16,12,10,13,12,5,12,18,14,19,16,8,20,5,20,8,8,9,14,14,13,16,11,13,5,18,8,19,18,11,11,9,6,17,16,12,10,10,7,7,12,11,13,7,11,11,19,7,5,18,18,15,9,19,15,10,6,12,12,18],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5} ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="691264eb-305f-44e4-aa9c-66ee66c2e58f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("691264eb-305f-44e4-aa9c-66ee66c2e58f")) {                    Plotly.newPlot(                        "691264eb-305f-44e4-aa9c-66ee66c2e58f",                        [{"alignmentgroup":"True","hovertemplate":"emergencyVisits=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[60,34,58,38,29,22,51,36,24,39,34,40,56,56,33,37,40,52,49,39,27,42,38,42,40,28,28,43,28,29,21,54,54,40,22,23,37,21,38,46,44,31,24,38,40,53,21,26,45,44,38,55,32,46,30,44,37,47,50,52,48,59,59,50,49,33,28,28,60,53,25,26,40,37,25,30,27,39,42,41,32,46,45,35,41,21,36,52,26,44],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line": ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5740c929-4a2b-4264-a6cb-46509639c471" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5740c929-4a2b-4264-a6cb-46509639c471")) {                    Plotly.newPlot(                        "5740c929-4a2b-4264-a6cb-46509639c471",                        [{"alignmentgroup":"True","hovertemplate":"surgeries=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[13,13,9,12,15,4,14,8,12,3,12,6,13,6,10,8,12,13,12,10,9,5,3,13,9,7,15,7,6,14,10,11,11,3,3,11,6,13,6,9,13,9,3,10,7,13,4,13,3,6,14,8,10,7,9,8,4,4,7,7,8,4,11,15,14,13,8,3,12,12,13,6,11,6,6,12,8,13,6,10,9,4,3,15,13,3,6,8,7,12],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="87dfa8ee-5a10-4e71-8222-e14287613813" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87dfa8ee-5a10-4e71-8222-e14287613813")) {                    Plotly.newPlot(                        "87dfa8ee-5a10-4e71-8222-e14287613813",                        [{"alignmentgroup":"True","hovertemplate":"revenue=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[120038,106975,134386,112336,70154,54161,118853,91066,119196,86446,117721,88856,53192,72284,96973,87513,105405,119397,101226,129411,148729,60213,111561,76874,78778,97800,124106,82228,57349,51847,105368,87101,119590,132379,131214,59385,91994,123065,145672,103615,96536,94129,103316,97491,83634,61254,114485,148818,146702,97586,89187,146474,139097,139894,126584,139053,147392,136147,83394,64752,146136,121923,114119,111421,143143,52641,51839,55292,57120,93312,82147,89199,97710,63298,142497,112379,94149,97062,61420,129222,130590,98782,108202,78430,88196,59076,107755,117072,92570,95661],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4d331a73-6432-46a1-b87f-254ab6097130" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d331a73-6432-46a1-b87f-254ab6097130")) {                    Plotly.newPlot(                        "4d331a73-6432-46a1-b87f-254ab6097130",                        [{"alignmentgroup":"True","hovertemplate":"expenses=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[77681,65743,68412,54216,112666,60120,99025,75377,112440,76514,55954,66029,116543,106786,64311,111867,111408,49275,72460,58012,69555,115963,53397,89329,47680,54289,88226,87670,92575,69751,53125,49224,112022,47663,87416,64384,49065,102258,89988,40430,112765,83421,116476,73426,114809,96952,114143,59055,94506,44412,45509,81314,84770,79332,82115,93351,100243,43989,102852,109065,57109,96611,51828,90986,45405,106410,41560,86357,116016,45141,44411,79771,81896,90751,97635,109256,96241,89750,84583,109281,97431,82128,89929,118816,81826,65621,49625,51181,69067,82032],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"t ...

# %% [markdown]
# ##### **Check Distributions of Numeric values**

# %%
# Count element per value
def nunique_values(data):
  for col in data.columns:
    if data[col].nunique() < 10 :
      print(f"{col} : {data[col].value_counts()} valeurs uniques")
      print("---------------------------------------")

# %%
# Patient Data

nunique_values(patient_data)
# Out:
# gender : gender
# Female    520
# Male      480
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# department : department
# Pediatrics    177
# Emergency     170
# Oncology      168
# Neurology     168
# Cardiology    161
# Surgery       156
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# treatment : treatment
# Medication        218
# Intensive Care    215
# Surgery           207
# Observation       202
# Therapy           158
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# outcome : outcome
# Recovered       508
# In Treatment    181
# Improved        153
# Stable           73
# Deteriorated     59
# Deceased         26
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# isAdmitted : isAdmitted
# False    819
# True     181
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------

# %%
# Staff Data

nunique_values(staff_data)
# Out:
# department : department
# Oncology          36
# Pediatrics        32
# Emergency         28
# Surgery           27
# Cardiology        27
# Neurology         26
# Administration    24
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# role : role
# Nurse             45
# Doctor            43
# Technician        40
# Support           38
# Administrative    34
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------

# %%
# Department Data

nunique_values(department_data)
# Out:
# department : department
# Cardiology    1
# Neurology     1
# Oncology      1
# Pediatrics    1
# Emergency     1
# Surgery       1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# totalPatients : totalPatients
# 168    2
# 161    1
# 177    1
# 170    1
# 156    1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# avgStayDuration : avgStayDuration
# 13.20    1
# 14.65    1
# 13.49    1
# 13.01    1
# 14.53    1
# 13.15    1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# totalRevenue : totalRevenue
# 7985903     1
# 9111593     1
# 9909357     1
# 7541597     1
# 9767089     1
# 10473640    1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# totalSalaries : totalSalaries
# 2611440    1
# 2556000    1
# 3603200    1
# 3002000    1
# 2680200    1
# 2516640    1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# operatingCost : operatingCost
# 2798682    1
# 2741313    1
# 3789201    1
# 3059114    1
# 2739548    1
# 2575019    1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# recoveryRate : recoveryRate
# 0.84    2
# 0.80    1
# 0.79    1
# 0.76    1
# 0.83    1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# bedsAvailable : bedsAvailable
# 50    1
# 40    1
# 60    1
# 45    1
# 30    1
# 35    1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# currentlyAdmitted : currentlyAdmitted
# 28    1
# 40    1
# 26    1
# 37    1
# 27    1
# 23    1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# bedUtilization : bedUtilization
# 0.56    1
# 1.00    1
# 0.43    1
# 0.82    1
# 0.90    1
# 0.66    1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# staffCount : staffCount
# 27    2
# 26    1
# 36    1
# 32    1
# 28    1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# doctorCount : doctorCount
# 3     2
# 7     2
# 11    1
# 8     1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# nurseCount : nurseCount
# 5     1
# 9     1
# 10    1
# 8     1
# 4     1
# 3     1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------

# %%
# Daily Metrics Data

nunique_values(metrics_data)

# %% [markdown]
# **Note** :
#
# - Le coût du traitement d’un cancer (oncologie) ne sera jamais comparable à celui d’une observation en pédiatrie.
#
# - Un chirurgien senior en cardiologie ne peut pas être comparé à une secrétaire en pédiatrie.

# %%
# Treatment Cost by Department

fig = px.box(patient_data, x='department', y='treatmentCost', color='treatment', title= "Treatment Cost by Department")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6a9e1db0-4b3b-41cf-a213-44bdd05379ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a9e1db0-4b3b-41cf-a213-44bdd05379ec")) {                    Plotly.newPlot(                        "6a9e1db0-4b3b-41cf-a213-44bdd05379ec",                        [{"alignmentgroup":"True","hovertemplate":"treatment=Observation\u003cbr\u003edepartment=%{x}\u003cbr\u003etreatmentCost=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"
# %%
# Salary by Role and Department

fig = px.box(staff_data, x='role', y='salary', color='department', title= "Salary by Role and Department")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="eb76ada1-4ac1-45c8-901a-58f2b82687a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eb76ada1-4ac1-45c8-901a-58f2b82687a8")) {                    Plotly.newPlot(                        "eb76ada1-4ac1-45c8-901a-58f2b82687a8",                        [{"alignmentgroup":"True","hovertemplate":"department=Emergency\u003cbr\u003erole=%{x}\u003cbr\u003esalary=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Emergency","marker":{"color":"#636efa"},"name":"Emergency","notched":false,"offsetgroup":"Emergency","orientation":"v","showlegend":true,"x":["Nurse","Technician","Support","Support","Doctor","Doctor","Doctor","Support","Administrative","Technician","Doctor","Support","Nurse","Nurse","Support","Doctor","Nurse","Support","Administrative","Doctor","Technician","Technician","Technician","Doctor","Technician","Doctor","Technician","Support"],"x0":" ","xaxis":"x","y":[93800,62400,42400,52000,172800,156000,170400,51200,59000,76800,165600,53600,95200,107800,41600,168000,74200,56800,61000,124800,85200,64800,86400,177600,96000,168000,62400,54400],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"department=Surgery\u003cbr\u003erole=%{x}\u003cbr\u003esalary=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Surgery","marker":{"color":"#EF553B"},"name":"Surgery","notched":false,"offsetgroup":"Surgery","orientation":"v","showlegend":true,"x":["Nurse","Administrative","Administrative","Nurse","Nurse","Doctor","Support","Support","Administrative","Doctor","Support","Doctor","Administrative","Support","Support","Technician","Technician","Administrative","Administrative","Support","Support","Technician","Administrative","Technician","Administrative","Administrative","Support"],"x0":" ","xaxis":"x","y":[132720,92400,81600,134400,122640,190080,66240,53760,76800,167040,51840,167040,67200,72960,52800,74880,102240,88800,86400,64320,53760,109440,92400,92160,85200,87600,49920],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"department=Oncology\u003cbr\u003erole=%{x}\u003cbr\u003esalary=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oncology","marker":{"color":"#00cc96"},"name":"Oncology","notched":false,"offsetgroup":"Oncology","orientation":"v","showlegend":true,"x":["Nurse","Nurse","Doctor","Doctor","Doctor","Administrative","Doctor","Technician","Administrative","Doctor","Nurse","Nurse","Doctor","Nurse","Support","Nurse","Technician","Support","Nurse","Administrative","Doctor","Technician","Doctor","Nurse","Administrative","Technician","Nurse","Administrative","Nurse","Doctor","Support","Doctor","Administrative","Technician","Support","Doctor"],"x0":" ","xaxis":"x","y":[91000,72800,163200,127200,158400,58000,120000,84000,58000,175200,105000,78400,165600,105000,57600,81200,88800,48800,93800,50000,182400,60000,172800,81200,54000,91200,102200,77000,77000,151200,40800,187200,67000,70800,57600,148800],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"department=Pediatrics\u003cbr\u003erole=%{x}\u003cbr\u003esalary=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pediatrics","marker":{"color":"#ab63fa"},"name":"Pediatrics","notched":false,"offsetgroup":"Pediatrics","orientation":"v","showlegend":true,"x":["Doctor","Administrative","Technician","Doctor","Support","Nurse","Administrative","Support","Support","Nurse","Administrative","Support","Technician","Technician","Nurse","Nurse","Nurse","Doctor","Technician","Technician","Nurse","Doctor","Support","Doctor","Nurse","Doctor","Nurse","Administrative","Support","Administrative","Doctor","Support"],"x0":" ","xaxis":"x","y":[184800,69000,94800,134400,55200,98000,60000,552 ...

# %% [markdown]
# **Note** :
#
# - Variability is controlled in each sub-group
#
# - There are no local outliers
#
# - The data generation model is consistent and realistic at subgroup level
#
# **Conclusion** :
#
# - There is no need to delete, winsorise or correct these values
#
# - Keep the data as it is for descriptive analysis, visualisation or even certain models.

# %%
# Filter important roles

patienthandled_filtered = staff_data[staff_data['role'].isin(['Doctor', 'Nurse'])]

# Doctors and nurses are those who handle patients

patienthandled_filtered
# Out:
#     staffId      department    role  yearsOfService  salary  patientsHandled  \
# 0     S1000       Emergency   Nurse              17   93800               79
# 1     S1001         Surgery   Nurse              29  132720               46
# 4     S1004         Surgery   Nurse              30  134400               44
# 5     S1005        Oncology   Nurse              15   91000               99
# 6     S1006      Pediatrics  Doctor              27  184800               81
# ..      ...             ...     ...             ...     ...              ...
# 187   S1187       Emergency  Doctor              20  168000               60
# 189   S1189  Administration  Doctor              10  144000               63
# 190   S1190      Cardiology   Nurse              29  132720               54
# 193   S1193       Neurology   Nurse              11   85400               20
# 197   S1197        Oncology  Doctor              12  148800               75
#
#      performanceScore
# 0                0.82
# 1                0.81
# 4                0.96
# 5                0.91
# 6                0.97
# ..                ...
# 187              0.98
# 189              0.91
# 190              0.73
# 193              0.70
# 197              0.81
#
# [88 rows x 7 columns]

# %%
# metrics_data.merge(patienthandled_filtered, on='staffId', how='inner')

# %%
#patienthandled_filtered.groupby('role')['patientsPerYear'].describe()

# %%
import plotly.express as px

fig = px.box(patienthandled_filtered, x='role', y='patientsHandled', color='department',
             title="Handled Patients by Role and Service")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4e13c944-4780-44df-95f3-86b9089ed744" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e13c944-4780-44df-95f3-86b9089ed744")) {                    Plotly.newPlot(                        "4e13c944-4780-44df-95f3-86b9089ed744",                        [{"alignmentgroup":"True","hovertemplate":"department=Emergency\u003cbr\u003erole=%{x}\u003cbr\u003epatientsHandled=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Emergency","marker":{"color":"#636efa"},"name":"Emergency","notched":false,"offsetgroup":"Emergency","orientation":"v","showlegend":true,"x":["Nurse","Doctor","Doctor","Doctor","Doctor","Nurse","Nurse","Doctor","Nurse","Doctor","Doctor","Doctor"],"x0":" ","xaxis":"x","y":[79,86,15,43,33,90,15,53,49,80,73,60],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"department=Surgery\u003cbr\u003erole=%{x}\u003cbr\u003epatientsHandled=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Surgery","marker":{"color":"#EF553B"},"name":"Surgery","notched":false,"offsetgroup":"Surgery","orientation":"v","showlegend":true,"x":["Nurse","Nurse","Nurse","Doctor","Doctor","Doctor"],"x0":" ","xaxis":"x","y":[46,44,83,91,27,26],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"department=Oncology\u003cbr\u003erole=%{x}\u003cbr\u003epatientsHandled=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oncology","marker":{"color":"#00cc96"},"name":"Oncology","notched":false,"offsetgroup":"Oncology","orientation":"v","showlegend":true,"x":["Nurse","Nurse","Doctor","Doctor","Doctor","Doctor","Doctor","Nurse","Nurse","Doctor","Nurse","Nurse","Nurse","Doctor","Doctor","Nurse","Nurse","Nurse","Doctor","Doctor","Doctor"],"x0":" ","xaxis":"x","y":[99,89,36,12,90,64,80,92,66,49,21,69,96,36,22,64,66,46,74,10,75],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"department=Pediatrics\u003cbr\u003erole=%{x}\u003cbr\u003epatientsHandled=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pediatrics","marker":{"color":"#ab63fa"},"name":"Pediatrics","notched":false,"offsetgroup":"Pediatrics","orientation":"v","showlegend":true,"x":["Doctor","Doctor","Nurse","Nurse","Nurse","Nurse","Nurse","Doctor","Nurse","Doctor","Doctor","Nurse","Doctor","Nurse","Doctor"],"x0":" ","xaxis":"x","y":[81,86,39,74,20,78,22,97,93,93,32,77,66,86,57],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"department=Cardiology\u003cbr\u003erole=%{x}\u003cbr\u003epatientsHandled=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cardiology","marker":{"color":"#FFA15A"},"name":"Cardiology","notched":false,"offsetgroup":"Cardiology","orientation":"v","showlegend":true,"x":["Doctor","Nurse","Nurse","Doctor","Doctor","Nurse","Nurse","Nurse"],"x0":" ","xaxis":"x","y":[60,82,99,89,64,10,98,54],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"department=Neurology\u003cbr\u003erole=%{x}\u003cbr\u003epatientsHandled=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Neurology","marker":{"color":"#19d3f3"},"name":"Neurology","notched":false,"offsetgroup":"Neurology","orientation":"v","showlegend":true,"x":["Nurse","Nurse","Nurse","Doctor","Doctor","Nurse","Doctor","Nurse","Doctor","Nurse","Doctor","Nurse","Nurse","Doctor","Doctor","Nurse"],"x0":" ","xaxis":"x","y":[35,39,48,95,92,56,64,46,32,88,46,71,24,19,50,20],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"department=Administration\u003cbr\u003erole=%{x}\u003cbr\u003epatientsHandled=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Administration","marker":{"color":"#FF6692"},"name":"Administration","notche ...

# %% [markdown]
# ##### **Handle Outliers**

# %%
outlier = patienthandled_filtered[patienthandled_filtered['patientsHandled'] == 12]
outlier
# Out:
#    staffId department    role  yearsOfService  salary  patientsHandled  \
# 27   S1027   Oncology  Doctor               3  127200               12
#
#     performanceScore
# 27              0.92

# %%
#Q1 = patienthandled_filtered['patientsHandled'].quantile(0.25)
#Q3 = patienthandled_filtered['patientsHandled'].quantile(0.75)
#IQR = Q3 - Q1
#upper_bound = Q3 + 1.5 * IQR
#ower_bound = Q1 - 1.5 * IQR

# Flatten the upper outliers

#patienthandled_filtered['patientsHandled'] = np.clip(patienthandled_filtered['patientsHandled'], None, upper_bound)
#patienthandled_filtered['patientsHandled'] = np.clip(patienthandled_filtered['patientsHandled'], None, lower_bound)

# %%
#import plotly.express as px

#fig = px.box(patienthandled_filtered, x='role', y='patientsHandled', color='department',
             #title="Handled Patients by Role and Service")
#fig.show()

# %%
# Delete the row

staff_data = staff_data[staff_data['staffId'] != 'S1116']

# %%
# Verification

staff_data[staff_data['staffId'] == 'S1116']
# Out:
# Empty DataFrame
# Columns: [staffId, department, role, yearsOfService, salary, patientsHandled, performanceScore]
# Index: []

# %%
# Customised thresholds

patienthandled_filtered['charge'] = pd.cut(patienthandled_filtered['patientsHandled'],
                               bins=[0, 10, 25, 50, 100],
                               labels=['Low', 'Moderate', 'High', 'Intense'])
# Out:
# /tmp/ipython-input-273-1665242455.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
patienthandled_filtered
# Out:
#     staffId      department    role  yearsOfService  salary  patientsHandled  \
# 0     S1000       Emergency   Nurse              17   93800               79
# 1     S1001         Surgery   Nurse              29  132720               46
# 4     S1004         Surgery   Nurse              30  134400               44
# 5     S1005        Oncology   Nurse              15   91000               99
# 6     S1006      Pediatrics  Doctor              27  184800               81
# ..      ...             ...     ...             ...     ...              ...
# 187   S1187       Emergency  Doctor              20  168000               60
# 189   S1189  Administration  Doctor              10  144000               63
# 190   S1190      Cardiology   Nurse              29  132720               54
# 193   S1193       Neurology   Nurse              11   85400               20
# 197   S1197        Oncology  Doctor              12  148800               75
#
#      performanceScore    charge
# 0                0.82   Intense
# 1                0.81      High
# 4                0.96      High
# 5                0.91   Intense
# 6                0.97   Intense
# ..                ...       ...
# 187              0.98   Intense
# 189              0.91   Intense
# 190              0.73   Intense
# 193              0.70  Moderate
# 197              0.81   Intense
#
# [88 rows x 8 columns]

# %%
# Save the final dataset

staff_data.to_json('./data/staff_cleaned.json', orient='records', indent=2)

# %% [markdown]
# ## **Data Analysis**

# %% [markdown]
# ### **Job Analysis/Statistics**
#
# - Moyenne, médiane par groupe
#
# - Comparaison de revenus entre services
#
# - Ratio coût/assurance par traitement

# %%
# Average and median treatmentCost by service/

Cost_summary = patient_data.groupby('department')['treatmentCost'].agg(['mean', 'median', 'std']).reset_index().sort_values(by='mean', ascending=False)
#Cost_summary

# %%
Cost_summary_ = Cost_summary.style \
    .background_gradient(subset=['mean'], cmap='YlGnBu') \
    .background_gradient(subset=['median'], cmap='YlOrRd') \
    .background_gradient(subset=['std'], cmap='Purples') \
    .format({
        'mean': "{:,.0f} $",
        'median': "{:,.0f} $",
        'std': "{:,.0f} $"
    }) \
    .set_caption("Mean, Median, Std by Department")

Cost_summary_
# Out:
# <style type="text/css">
# #T_bc7d2_row0_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_bc7d2_row0_col2 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_bc7d2_row0_col3 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_bc7d2_row1_col1 {
#   background-color: #1f80b8;
#   color: #f1f1f1;
# }
# #T_bc7d2_row1_col2 {
#   background-color: #fb4b29;
#   color: #f1f1f1;
# }
# #T_bc7d2_row1_col3 {
#   background-color: #786db2;
#   color: #f1f1f1;
# }
# #T_bc7d2_row2_col1 {
#   background-color: #2397c1;
#   color: #f1f1f1;
# }
# #T_bc7d2_row2_col2 {
#   background-color: #ec2c21;
#   color: #f1f1f1;
# }
# #T_bc7d2_row2_col3 {
#   background-color: #8e8bc1;
#   color: #f1f1f1;
# }
# #T_bc7d2_row3_col1 {
#   background-color: #4ebbc2;
#   color: #000000;
# }
# #T_bc7d2_row3_col2 {
#   background-color: #fd7234;
#   color: #f1f1f1;
# }
# #T_bc7d2_row3_col3 {
#   background-color: #f1eff6;
#   color: #000000;
# }
# #T_bc7d2_row4_col1 {
#   background-color: #b4e2b6;
#   color: #000000;
# }
# #T_bc7d2_row4_col2 {
#   background-color: #fec35e;
#   color: #000000;
# }
# #T_bc7d2_row4_col3 {
#   background-color: #e4e3f0;
#   color: #000000;
# }
# #T_bc7d2_row5_col1 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_bc7d2_row5_col2 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_bc7d2_row5_col3 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_bc7d2" class="dataframe">
#   <caption>Mean, Median, Std by Department</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc7d2_level0_col0" class="col_heading level0 col0" >department</th>
#       <th id="T_bc7d2_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_bc7d2_level0_col2" class="col_heading level0 col2" >median</th>
#       <th id="T_bc7d2_level0_col3" class="col_heading level0 col3" >std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc7d2_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_bc7d2_row0_col0" class="data row0 col0" >Surgery</td>
#       <td id="T_bc7d2_row0_col1" class="data row0 col1" >67,139 $</td>
#       <td id="T_bc7d2_row0_col2" class="data row0 col2" >55,644 $</td>
#       <td id="T_bc7d2_row0_col3" class="data row0 col3" >53,378 $</td>
#     </tr>
#     <tr>
#       <th id="T_bc7d2_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_bc7d2_row1_col0" class="data row1 col0" >Oncology</td>
#       <td id="T_bc7d2_row1_col1" class="data row1 col1" >58,984 $</td>
#       <td id="T_bc7d2_row1_col2" class="data row1 col2" >43,672 $</td>
#       <td id="T_bc7d2_row1_col3" class="data row1 col3" >50,052 $</td>
#     </tr>
#     <tr>
#       <th id="T_bc7d2_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_bc7d2_row2_col0" class="data row2 col0" >Emergency</td>
#       <td id="T_bc7d2_row2_col1" class="data row2 col1" >57,453 $</td>
#       <td id="T_bc7d2_row2_col2" class="data row2 col2" >45,996 $</td>
#       <td id="T_bc7d2_row2_col3" class="data row2 col3" >48,987 $</td>
#     </tr>
#     <tr>
#       <th id="T_bc7d2_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_bc7d2_row3_col0" class="data row3 col0" >Neurology</td>
#       <td id="T_bc7d2_row3_col1" class="data row3 col1" >54,236 $</td>
#       <td id="T_bc7d2_row3_col2" class="data row3 col2" >41,068 $</td>
#       <td id="T_bc7d2_row3_col3" class="data row3 col3" >44,345 $</td>
#     </tr>
#     <tr>
#       <th id="T_bc7d2_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_bc7d2_row4_col0" class="data row4 col0" >Cardiology</td>
#       <td id="T_bc7d2_row4_col1" class="data row4 col1" >49,602 $</td>
#       <td id="T_bc7d2_row4_col2" class="data row4 col2" >33,617 $</td>
#       <td id="T_bc7d2_row4_col3" class="data row4 col3" >45,199 $</td>
#     </tr>
#     <tr>
#       <th id="T_bc7d2_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_bc7d2_row5_col0" class="data row5 col0" >Pediatrics</td>
#       <td id="T_bc7d2_row5_col1" class="data row5 col1" >42,608 $</td>
#       <td id="T_bc7d2_row5_col2" class="data row5 col2" >23,133 $</td>
#       <td id="T_bc7d2_row5_col3" class="data row5 col3" >43,271 $</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### **Salary Analysis**

# %%
department_colors = {
    'Surgery':       {'bg': '#E3F2FD', 'text': '#0D47A1'},  # Bleu clair + bleu foncé
    'Cardiology':    {'bg': '#FCE4EC', 'text': '#AD1457'},  # Rose pâle + rose foncé
    'Neurology':     {'bg': '#EDE7F6', 'text': '#4527A0'},  # Lavande + violet foncé
    'Pediatrics':    {'bg': '#E8F5E9', 'text': '#1B5E20'},  # Vert menthe + vert foncé
    'Emergency':     {'bg': '#FFF8E1', 'text': '#FF6F00'},  # Jaune doux + orange foncé
    'Oncology':      {'bg': '#FFEBEE', 'text': '#B71C1C'},  # Rouge clair + rouge foncé
    'Administration':{'bg': '#E3F2FD', 'text': '#1565C0'},  # Bleu clair + bleu classique
}

# %%
def style_department(row):
    dept = row['department']
    if dept in department_colors:
        bg = department_colors[dept]['bg']
        text = department_colors[dept]['text']
        return [f'background-color: {bg}; color: {text};'] * len(row)
    return [''] * len(row)

# %%
def highlight_salary(val):
    if val > 150000:
        return 'background-color: #D1C4E9; color: #311B92; font-weight: bold;'  # Violet doux
    elif val > 100000:
        return 'background-color: #FFF9C4; color: #F57F17;'  # Jaune pastel
    return 'background-color: #FFCDD2; color: #C62828;'      # Rouge clair

# %%
styled_df = staff_data[['staffId', 'department', 'role', 'salary']].sort_values('salary', ascending=False)

styled_df.style \
    .applymap(highlight_salary, subset=['salary']) \
    .apply(style_department, axis=1) \
    .bar(subset=['salary'], color='#A5D6A7') \
    .set_caption("Salaires du personnel hospitalier — codés par service & hiérarchie")
# Out:
# /tmp/ipython-input-281-4284644361.py:4: FutureWarning:
#
# Styler.applymap has been deprecated. Use Styler.map instead.
# <style type="text/css">
# #T_18ae8_row0_col0, #T_18ae8_row0_col1, #T_18ae8_row0_col2, #T_18ae8_row6_col0, #T_18ae8_row6_col1, #T_18ae8_row6_col2, #T_18ae8_row13_col0, #T_18ae8_row13_col1, #T_18ae8_row13_col2, #T_18ae8_row41_col0, #T_18ae8_row41_col1, #T_18ae8_row41_col2, #T_18ae8_row47_col0, #T_18ae8_row47_col1, #T_18ae8_row47_col2, #T_18ae8_row48_col0, #T_18ae8_row48_col1, #T_18ae8_row48_col2, #T_18ae8_row52_col0, #T_18ae8_row52_col1, #T_18ae8_row52_col2, #T_18ae8_row63_col0, #T_18ae8_row63_col1, #T_18ae8_row63_col2, #T_18ae8_row69_col0, #T_18ae8_row69_col1, #T_18ae8_row69_col2
126_col2, #T_18ae8_row129_col0, #T_18ae8_row129_col1, #T_18ae8_row129_col2, #T_18ae8_row134_col0, #T_18ae8_row134_col1, #T_18ae8_row134_col2, #T_18ae8_row136_col0, #T_18ae8_row136_col1, #T_18ae8_row136_col2, #T_18ae8_row137_col0, #T_18ae8_row137_col1, #T_18ae8_row137_col2, #T_18ae8_row141_col0, #T_18ae8_row141_col1, #T_18ae8_row141_col2, #T_18ae8_row164_col0, #T_18ae8_row164_col1, #T_18ae8_row164_col2, #T_18ae8_row181_col0, #T_18ae8_row181_col1, #T_18ae8_row181_col2, #T_18ae8_row187_col0, #T_18ae8_row187_col1, #T_18ae8_row187_col2, #T_18ae8_row189_col0, #T_18ae8_row189_col1, #T_18ae8_row189_col2 {
#   background-color: #EDE7F6;
#   color: #4527A0;
# }
# #T_18ae8_row1_col3 {
#   background-color: #D1C4E9;
#   color: #311B92;
#   font-weight: bold;
#   background-color: #EDE7F6;
#   color: #4527A0;
#   width: 10em;
#   background: linear-gradient(90deg, #A5D6A7 98.0%, transparent 98.0%);
# }
# #T_18ae8_row2_col0, #T_18ae8_row2_col1, #T_18ae8_row2_col2, #T_18ae8_row4_col0, #T_18ae8_row4_col1, #T_18ae8_row4_col2, #T_18ae8_row7_col0, #T_18ae8_row7_col1, #T_18ae8_row7_col2, #T_18ae8_row17_col0, #T_18ae8_row17_col1, #T_18ae8_row17_col2, #T_18ae8_row27_col0, #T_18ae8_row27_col1, #T_18ae8_row27_col2, #T_18ae8_row34_col0, #T_18ae8_row34_col1, #T_18ae8_row34_col2, #T_18ae8_row38_col0, #T_18ae8_row38_col1, #T_18ae8_row38_col2, #T_18ae8_row49_col0, #T_18ae8_row49_col1, #T_18ae8_row49_col2, #T_18ae8_row59_col0, #T_18ae8_row59_col1, #T_18ae8_row59_col2, #T_18ae8_row60_col0, #T_18ae8_row60_col1, #T_18ae8_row60_col2, #T_18ae8_row61_col0, #T_18ae8_row61_col1, #T_18ae8_row61_col2, #T_18ae8_row64_col0, #T_18ae8_row64_col1, #T_18ae8_row64_col2, #T_18ae8_row71_col0, #T_18ae8_row71_col1, #T_18ae8_row71_col2, #T_18ae8_row72_col0, #T_18ae8_row72_col1, #T_18ae8_row72_col2, #T_18ae8_row102_col0, #T_18ae8_row102_col1, #T_18ae8_row102_col2, #T_18ae8_row107_col0, #T_18ae8_row107_col1, #T_18ae8_row107_col2, #T_18ae8_row112_col0, #T_18ae8_row112_col1, #T_18ae8_row112_col2, #T_18ae8_row123_col0, #T_18ae8_row123_col1, #T_18ae8_row123_col2, #T_18ae8_row133_col0, #T_18ae8_row133_col1, #T_18ae8_row133_col2, #T_18ae8_row139_col0, #T_18ae8_row139_col1, #T_18ae8_row139_col2, #T_18ae8_row147_col0, #T_18ae8_row147_col1, #T_18ae8_row147_col2, #T_18ae8_row153_col0, #T_18ae8_row153_col1, #T_18ae8_row153_col2, #T_18ae8_row159_col0, #T_18ae8_row159_col1, #T_18ae8_row159_col2, #T_18ae8_row161_col0, #T_18ae8_row161_col1, #T_18ae8_row161_col2, #T_18ae8_row168_col0, #T_18ae8_row168_col1, #T_18ae8_row168_col2, #T_18ae8_row169_col0, #T_18ae8_row169_col1, #T_18ae8_row169_col2, #T_18ae8_row170_col0, #T_18ae8_row170_col1, #T_18ae8_row170_col2, #T_18ae8_row177_col0, #T_18ae8_row177_col1, #T_18ae8_row177_col2, #T_18ae8_row191_col0, #T_18ae8_row191_col1, #T_18ae8_row191_col2, #T_18ae8_row193_col0, #T_18ae8_row193_col1, #T_18ae8_row193_col2, #T_18ae8_row196_col0, #T_18ae8_row196_col1, #T_18ae8_row196_col2 {
#   background-color: #E8F5E9;
#   color: #1B5E20;
# }
# #T_18ae8_row2_col3 {
#   background-color: #D1C4E9;
#   color: #311B92;
#   font-weight: bold;
#   background-color: #E8F5E9;
#   color: #1B5E20;
#   width: 10em;
#   background: linear-gradient(90deg, #A5D6A7 98.0%, transparent 98.0%);
# }
# #T_18ae8_row3_col0, #T_18ae8_row3_col1, #T_18ae8_row3_col2, #T_18ae8_row20_col0, #T_18ae8_row20_col1, #T_18ae8_row20_col2, #T_18ae8_row21_col0, #T_18ae8_row21_col1, #T_18ae8_row21_col2, #T_18ae8_row39_col0, #T_18ae8_row39_col1, #T_18ae8_row39_col2, #T_18ae8_row40_col0, #T_18ae8_row40_col1, #T_18ae8_row40_col2, #T_18ae8_row44_col0, #T_18ae8_row44_col1, #T_18ae8_row44_col2, #T_18ae8_row50_col0, #T_18ae8_row50_col1, #T_18ae8_row50_col2, #T_18ae8_row57_col0, #T_18ae8_row57_col1, #T_18ae8_row57_col2, #T_18ae8_row76_col0, #T_18ae8_row76_col1, #T_18ae8_row76_col2, #T_18ae8_row77_col0, #T_18ae8_row77_col1, #T_18ae8_row77_col2, #T_18ae8_row78_col0, #T_18ae8_row78_col1, #T_18ae8_row78_col2, #T_18ae8_row87_col0, #T_18ae8_row87_col1, #T_18ae8_row87_col2, #T_18ae8_row90_col0, #T_18ae8_row90_col1, #T_18ae8_row90_col2, #T_18ae8_row92_col0, #T_18ae8_row92_col1, #T_18ae8_row92_col2, #T_18ae8_row98_col0, #T_18ae8_row98_col1, #T_18ae8_row98_col2, #T_18ae8_row105_col0, #T_18ae8_row105_col1, #T_18ae8_row105_col2, #T_18ae8_row121_col0, #T_18ae8_row121_col1, #T_18ae8_row121_col2, #T_18ae8_row127_col0, #T_18ae8_row127_col1, #T_18ae8_row127_col2, #T_18ae8_row131_col0, #T_18ae8_row131_col1, #T_18ae8_row131_col2, #T_18ae8_row143_col0, #T_18ae8_row143_col1, #T_18ae8_row143_col2, #T_18ae8_row145_col0, #T_18ae8_row145_col1, #T_18ae8_row145_col2, #T_18ae8_row149_col0, #T_18ae8_row149_col1, #T_18ae8_row149_col2, #T_18ae8_row173_col0, #T_18ae8_row173_col1, #T_18ae8_row173_col2, #T_18ae8_row174_col0, #T_18ae8_row174_col1, #T_18ae8_row174_col2, #T_18ae8_row176_col0, #T_18ae8_row176_col1, #T_18ae8_row176_col2, #T_18ae8_row179_col0, #T_18ae8_row179_col1, #T_18ae8_row179_col2, #T_18ae8_row185_col0, #T_18ae8_row185_col1, #T_18ae8_row185_col2 {
#   background-color:

# %%
# Distribution of costs by department

fig = px.histogram(
    patient_data,
    x='treatmentCost',
    color='department',
    facet_col='department',
    facet_col_wrap=3,
    nbins=30,
    title="Distribution of costs by department",
    color_discrete_sequence=px.colors.sequential.BuPu_r
)
fig.update_layout(showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c
=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Neurology","marker":{"color":"rgb(136,65,157)","opacity":0.6,"pattern":{"shape":""}},"name":"Neurology","nbinsx":50,"offsetgroup":"Neurology","orientation":"v","showlegend":true,"x":[98642,19183,26979,31099,14596,11614,11687,17253,109041,26118,201075,103115,22075,23172,36732,91774,40446,25474,27450,21073,72057,14698,99177,7261,28810,83686,104822,18077,17463,5380,19709,28329,23561,43408,30027,16968,117515,13001,10110,83041,1 ...

# %%
# Add OutOfPocket column : Treatment Cost - Insurance Covered

patient_data['outOfPocket'] = patient_data['treatmentCost'] - patient_data['insuranceCovered']

# %%
fig = px.strip(
    patient_data,
    x='department',
    y='outOfPocket',
    color='department',
    title="Patients vs. Out-of-pocket expenses per service",
    stripmode='overlay',
    color_discrete_sequence=px.colors.sequential.BuPu_r
)
fig.update_layout(yaxis_title='uncovered amount')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8de5cecb-3df8-4158-9778-f8d41de6ba0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8de5cecb-3df8-4158-9778-f8d41de6ba0f")) {                    Plotly.newPlot(                        "8de5cecb-3df8-4158-9778-f8d41de6ba0f",                        [{"alignmentgroup":"True","boxpoints":"all","fillcolor":"rgba(255,255,255,0)","hoveron":"points","hovertemplate":"department=%{x}\u003cbr\u003eoutOfPocket=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cardiology","line":{"color":"rgba(255,255,255,0)"},"marker":{"color":"rgb(77,0,75)"},"name":"Cardiology","offsetgroup":"Cardiology","orientation":"v","pointpos":0,"showlegend":true,"x":["Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology","Cardiology"],"x0":" ","xaxis":"x","y":[1898,5511,9409,1671,6078,936,12414,5308,8513,2131,5881,1477,796,596,8421,3371,8663,6604,370,16397,10216,2273,6984,621,221,1533,20452,8980,6041,1332,3360,24750,4201,4323,5779,39304,4032,601,628,4363,28675,3590,547,607,6302,2792,2607,534,12019,3438,4658,16196,4511,1312,1970,3036,33259,16628,1169,1228,1632,1280,1871,5767,6469,25696,3285,14787,1793,11906,16202,1346,23633,4818,16367,11087,18917,8821,16838,14045,2915,28419,14015,6050,13915,11206,4535,4491,6813,8861,18555,4393,38137,6973,4113,7763,9955,26071,1105,8337,20288,10377,3076,5650,19859,7139,3324,7020,509,2140,6434,3991,12669,1785,14829,2326,1139,23366,7184,24042,4222,12838,20069,9466,2018,3076,8696,15311,12237,13210,52452,3115,31945,3565,3460,788,1623,20710,6283,400,3537,9633,2912,2952,5155,1522,16347,4947,22798,2847,8559,9478,12524,3858,6254,3277,152,15682,904,4077,7854],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"all", ...

# %%
# Average out-of-pocket expenses by department

agg_out_of_pocket = (
    patient_data.groupby('department')['outOfPocket']
    .mean()
    .reset_index()
    .sort_values(by='outOfPocket', ascending=False)
)

fig = px.bar(
    agg_out_of_pocket,
    x='department',
    y='outOfPocket',
    color='department',
    title='Average charges by department',
    labels={'outOfPocket': 'Average amount not covered'},
    color_discrete_sequence=px.colors.sequential.BuPu_r
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9f3afeb4-2030-4989-be01-b4f2139a42e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f3afeb4-2030-4989-be01-b4f2139a42e2")) {                    Plotly.newPlot(                        "9f3afeb4-2030-4989-be01-b4f2139a42e2",                        [{"alignmentgroup":"True","hovertemplate":"department=%{x}\u003cbr\u003eAverage amount not covered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Surgery","marker":{"color":"rgb(77,0,75)","pattern":{"shape":""}},"name":"Surgery","offsetgroup":"Surgery","orientation":"v","showlegend":true,"textposition":"auto","x":["Surgery"],"xaxis":"x","y":[11403.916666666666],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"department=%{x}\u003cbr\u003eAverage amount not covered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Emergency","marker":{"color":"rgb(129,15,124)","pattern":{"shape":""}},"name":"Emergency","offsetgroup":"Emergency","orientation":"v","showlegend":true,"textposition":"auto","x":["Emergency"],"xaxis":"x","y":[9408.14705882353],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"department=%{x}\u003cbr\u003eAverage amount not covered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oncology","marker":{"color":"rgb(136,65,157)","pattern":{"shape":""}},"name":"Oncology","offsetgroup":"Oncology","orientation":"v","showlegend":true,"textposition":"auto","x":["Oncology"],"xaxis":"x","y":[9396.672619047618],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"department=%{x}\u003cbr\u003eAverage amount not covered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Neurology","marker":{"color":"rgb(140,107,177)","pattern":{"shape":""}},"name":"Neurology","offsetgroup":"Neurology","orientation":"v","showlegend":true,"textposition":"auto","x":["Neurology"],"xaxis":"x","y":[9029.404761904761],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"department=%{x}\u003cbr\u003eAverage amount not covered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cardiology","marker":{"color":"rgb(140,150,198)","pattern":{"shape":""}},"name":"Cardiology","offsetgroup":"Cardiology","orientation":"v","showlegend":true,"textposition":"auto","x":["Cardiology"],"xaxis":"x","y":[8587.57142857143],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"department=%{x}\u003cbr\u003eAverage amount not covered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pediatrics","marker":{"color":"rgb(158,188,218)","pattern":{"shape":""}},"name":"Pediatrics","offsetgroup":"Pediatrics","orientation":"v","showlegend":true,"textposition":"auto","x":["Pediatrics"],"xaxis":"x","y":[7409.881355932203],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colo ...

# %%
# Distribution of work loads

fig = px.pie(patienthandled_filtered, names='charge', title="Distribution of work loads", color_discrete_sequence=px.colors.sequential.RdBu)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d431a196-c785-4b89-8760-2f59a965d2f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d431a196-c785-4b89-8760-2f59a965d2f4")) {                    Plotly.newPlot(                        "d431a196-c785-4b89-8760-2f59a965d2f4",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"charge=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Intense","High","High","Intense","Intense","Intense","Intense","High","Intense","Intense","High","Moderate","Intense","High","High","Intense","High","Intense","Intense","Moderate","Intense","High","Intense","High","High","Intense","Intense","Intense","High","Intense","High","Intense","High","Intense","Moderate","High","Intense","Intense","Moderate","Intense","Intense","Moderate","Moderate","Intense","Moderate","Intense","Intense","Intense","Intense","Intense","Intense","Intense","High","Intense","Intense","High","High","Intense","Intense","High","High","Intense","Moderate","Intense","High","Intense","Low","Moderate","Intense","Intense","Intense","Moderate","Intense","Intense","High","Intense","Intense","Low","High","Intense","Low","Intense","Intense","Intense","Intense","Intense","Moderate","Intense"],"legendgroup":"","name":"","showlegend":true,"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921" ...

# %% [markdown]
# ### **Alerts Definition**

# %% [markdown]
# **Critiques** :
#
# - Bed Utilization Rate (Elevé if > 90%)
# - Taux de retablissement faible (if < 70%)
# - Ratio personnel / patient

# %%
alertes = []

# %%
for it in department_data.iterrows():
  #print(it)
  pass

# %%
# Define Alerts

alertes = []

# %%
department_data['bedUtilization'].unique()
# Out:
# array([0.56, 1.  , 0.43, 0.82, 0.9 , 0.66])

# %%
# High Bed Utilization Rate

# Serious Alerts

for _, dept in department_data.iterrows():
  # Alerte de taux d'occupation élevé
  if dept['bedUtilization'] > 0.9:
    alertes.append({
    'titre': f"Taux d'occupation critique en {dept['department']}",
    'message': f"Le taux d'occupation des lits est de {dept['bedUtilization']*100:.1f}% ({dept['currentlyAdmitted']} patients pour {dept['bedsAvailable']} lits).",
    'departement': dept['department'],
    'type': 'critique'
    })

alertes
# Out:
# [{'titre': "Taux d'occupation critique en Neurology",
#   'message': "Le taux d'occupation des lits est de 100.0% (40 patients pour 40 lits).",
#   'departement': 'Neurology',
#   'type': 'critique'}]

# %%
# Low Recovery Rate Alerts

if dept['recoveryRate'] < 0.7:
  alertes.append({
      'titre': f"Taux de rétablissement faible en {dept['department']}",
      'message': f"Le taux de rétablissement est de seulement {dept['recoveryRate']*100:.1f}%, ce qui est inférieur à l'objectif de 70%.",
      'departement': dept['department'],
      'type': 'critique'
      })

alertes
# Out:
# [{'titre': "Taux d'occupation critique en Neurology",
#   'message': "Le taux d'occupation des lits est de 100.0% (40 patients pour 40 lits).",
#   'departement': 'Neurology',
#   'type': 'critique'}]

# %%
# Ratio Doctor/Patients Alerts

ratio_medecins = dept['doctorCount'] / max(1, dept['totalPatients'])
if ratio_medecins < 0.1:  # Moins de 1 médecin pour 10 patients
  alertes.append({
      'titre': f"Manque de médecins en {dept['department']}",
      'message': f"Ratio médecin/patients de 1:{int(1/ratio_medecins)}, ce qui est inférieur aux recommandations.",
      'departement': dept['department'],
      'type': 'critique'
      })

max(1, dept['totalPatients'])
# Out:
# 156

# %%
print(ratio_medecins)
# Out:
# 0.019230769230769232

# %%
print(alertes)
# Out:
# [{'titre': "Taux d'occupation critique en Neurology", 'message': "Le taux d'occupation des lits est de 100.0% (40 patients pour 40 lits).", 'departement': 'Neurology', 'type': 'critique'}, {'titre': 'Manque de médecins en Surgery', 'message': 'Ratio médecin/patients de 1:52, ce qui est inférieur aux recommandations.', 'departement': 'Surgery', 'type': 'critique'}]

# %%
# Ratio Doctor/Patients Alerts

ratio_medecins = dept['doctorCount'] / dept['totalPatients']
if ratio_medecins < 0.1:  # Moins de 1 médecin pour 10 patients
  alertes.append({
      'titre': f"Manque de médecins en {dept['department']}",
      'message': f"Ratio médecin/patients de 1:{int(1/ratio_medecins)}, ce qui est inférieur aux recommandations.",
      'departement': dept['department'],
      'type': 'critique'
      })

alertes
ratio_medecins
# max(1, dept['totalPatients'])
# Out:
# 0.019230769230769232

# %%
# Display Alertes Dataframe

pd.DataFrame(alertes)
# Out:
#                                      titre  \
# 0  Taux d'occupation critique en Neurology
# 1            Manque de médecins en Surgery
# 2            Manque de médecins en Surgery
#
#                                              message departement      type
# 0  Le taux d'occupation des lits est de 100.0% (4...   Neurology  critique
# 1  Ratio médecin/patients de 1:52, ce qui est inf...     Surgery  critique
# 2  Ratio médecin/patients de 1:52, ce qui est inf...     Surgery  critique

# %% [markdown]
# **Générales**
#
# - Tendance Admission / Sorties
# - Alertes financières

# %%
# Admission vs. Discharges

metrics_data
# Out:
#          date  newAdmissions  discharges  emergencyVisits  surgeries  revenue  \
# 0  2025-04-22             22           8               60         13   120038
# 1  2025-04-23             23           8               34         13   106975
# 2  2025-04-24              6           9               58          9   134386
# 3  2025-04-25             17           5               38         12   112336
# 4  2025-04-26             15          17               29         15    70154
# ..        ...            ...         ...              ...        ...      ...
# 85 2025-07-16             25          10               21          3    59076
# 86 2025-07-17             22           6               36          6   107755
# 87 2025-07-18              7          12               52          8   117072
# 88 2025-07-19             11          12               26          7    92570
# 89 2025-07-20             12          18               44         12    95661
#
#     expenses
# 0      77681
# 1      65743
# 2      68412
# 3      54216
# 4     112666
# ..       ...
# 85     65621
# 86     49625
# 87     51181
# 88     69067
# 89     82032
#
# [90 rows x 7 columns]

# %%
len(metrics_data)
# Out:
# 90

# %%
derniere_semaine = metrics_data.sort_values('date').tail(7)

# %%
admissions = derniere_semaine['newAdmissions'].sum()

admissions
# Out:
# np.int64(106)

# %%
sorties = derniere_semaine['discharges'].sum()

sorties
# Out:
# np.int64(92)

# %%
derniere_semaine
# Out:
#          date  newAdmissions  discharges  emergencyVisits  surgeries  revenue  \
# 83 2025-07-14              9          19               35         15    78430
# 84 2025-07-15             20          15               41         13    88196
# 85 2025-07-16             25          10               21          3    59076
# 86 2025-07-17             22           6               36          6   107755
# 87 2025-07-18              7          12               52          8   117072
# 88 2025-07-19             11          12               26          7    92570
# 89 2025-07-20             12          18               44         12    95661
#
#     expenses
# 83    118816
# 84     81826
# 85     65621
# 86     49625
# 87     51181
# 88     69067
# 89     82032

# %%
# Admissions vs Discharges Trend

if len(metrics_data) >= 7:  # Au moins une semaine de données
    derniere_semaine = metrics_data.sort_values('date').tail(7)
    admissions = derniere_semaine['newAdmissions'].sum()
    sorties = derniere_semaine['discharges'].sum()
    if admissions > sorties * 1.3:  # 30% plus d'admissions que de sorties
      alertes.append({
          'titre': "Déséquilibre admissions/sorties",
          'message': f"Sur les 7 derniers jours, il y a eu {admissions} admissions pour seulement {sorties} sorties, ce qui indique une pression croissante sur les capacités.",
          'departement': 'Tous',
          'type': 'avertissement'
          })

# %%
if len(metrics_data) >= 7:  # Au moins une semaine de données
    derniere_semaine = metrics_data.sort_values('date').tail(7)
    admissions = derniere_semaine['newAdmissions'].sum()
    sorties = derniere_semaine['discharges'].sum()
    if admissions > sorties * 1.3:  # 30% plus d'admissions que de sorties
      alertes.append({
          'titre': "Déséquilibre admissions/sorties",
          'message': f"Sur les 7 derniers jours, il y a eu {admissions} admissions pour seulement {sorties} sorties, ce qui indique une pression croissante sur les capacités.",
          'departement': 'Tous',
          'type': 'avertissement'
          })

alertes
# Out:
# [{'titre': "Taux d'occupation critique en Neurology",
#   'message': "Le taux d'occupation des lits est de 100.0% (40 patients pour 40 lits).",
#   'departement': 'Neurology',
#   'type': 'critique'},
#  {'titre': 'Manque de médecins en Surgery',
#   'message': 'Ratio médecin/patients de 1:52, ce qui est inférieur aux recommandations.',
#   'departement': 'Surgery',
#   'type': 'critique'},
#  {'titre': 'Manque de médecins en Surgery',
#   'message': 'Ratio médecin/patients de 1:52, ce qui est inférieur aux recommandations.',
#   'departement': 'Surgery',
#   'type': 'critique'}]

# %%
# Test

if admissions > sorties * 1.3:  # 30% plus d'admissions que de sorties
  alertes.append({
      'titre': "Déséquilibre admissions/sorties",
      'message': f"Sur les 7 derniers jours, il y a eu {admissions} admissions pour seulement {sorties} sorties, ce qui indique une pression croissante sur les capacités.",
      'departement': 'Tous',
      'type': 'avertissement'
      })
  print(alertes)
else:
  print(f"Capacité non pressante : Il y a eu {admissions} admissions pour {sorties} sorties.")
# Out:
# Capacité non pressante : Il y a eu 106 admissions pour 92 sorties.

# %%
metrics_data
# Out:
#          date  newAdmissions  discharges  emergencyVisits  surgeries  revenue  \
# 0  2025-04-22             22           8               60         13   120038
# 1  2025-04-23             23           8               34         13   106975
# 2  2025-04-24              6           9               58          9   134386
# 3  2025-04-25             17           5               38         12   112336
# 4  2025-04-26             15          17               29         15    70154
# ..        ...            ...         ...              ...        ...      ...
# 85 2025-07-16             25          10               21          3    59076
# 86 2025-07-17             22           6               36          6   107755
# 87 2025-07-18              7          12               52          8   117072
# 88 2025-07-19             11          12               26          7    92570
# 89 2025-07-20             12          18               44         12    95661
#
#     expenses
# 0      77681
# 1      65743
# 2      68412
# 3      54216
# 4     112666
# ..       ...
# 85     65621
# 86     49625
# 87     51181
# 88     69067
# 89     82032
#
# [90 rows x 7 columns]

# %%
# Financial Alerts
if len(metrics_data) >= 30:  # Au moins un mois de données
  dernier_mois = metrics_data.sort_values('date').tail(30)
  revenus = dernier_mois['revenue'].sum()
  depenses = dernier_mois['expenses'].sum()
  if depenses > revenus:
    alertes.append({
        'titre': "Déficit financier",
        'message': f"Sur les 30 derniers jours, les dépenses ({depenses}) ont dépassé les revenus ({revenus}), créant un déficit de {(depenses-revenus)}.",
        'departement': 'Tous',
        'type': 'avertissement'
            })

# %%
# Financial Alerts Test

if len(metrics_data) >= 30:  # Au moins un mois de données
  dernier_mois = metrics_data.sort_values('date').tail(30)
  revenus = dernier_mois['revenue'].sum()
  depenses = dernier_mois['expenses'].sum()
  if depenses > revenus:
    alertes.append({
        'titre': "Déficit financier",
        'message': f"Sur les 30 derniers jours, les dépenses ({depenses}) ont dépassé les revenus ({revenus}), créant un déficit de {(depenses-revenus)}.",
        'departement': 'Tous',
        'type': 'avertissement'
            })
  else :
    print(f"Pas de problème financier : Les revenus ({(revenus)}) sont supérieurs aux dépenses ({(depenses)}), créant un profit de {(revenus-depenses)}.")
# Out:
# Pas de problème financier : Les revenus (2892363) sont supérieurs aux dépenses (2408654), créant un profit de 483709.

# %%
# Display Alert

alertes
# Out:
# [{'titre': "Taux d'occupation critique en Neurology",
#   'message': "Le taux d'occupation des lits est de 100.0% (40 patients pour 40 lits).",
#   'departement': 'Neurology',
#   'type': 'critique'},
#  {'titre': 'Manque de médecins en Surgery',
#   'message': 'Ratio médecin/patients de 1:52, ce qui est inférieur aux recommandations.',
#   'departement': 'Surgery',
#   'type': 'critique'},
#  {'titre': 'Manque de médecins en Surgery',
#   'message': 'Ratio médecin/patients de 1:52, ce qui est inférieur aux recommandations.',
#   'departement': 'Surgery',
#   'type': 'critique'}]

# %%
# Display Alert Dataframe

pd.DataFrame(alertes)
# Out:
#                                      titre  \
# 0  Taux d'occupation critique en Neurology
# 1            Manque de médecins en Surgery
# 2            Manque de médecins en Surgery
#
#                                              message departement      type
# 0  Le taux d'occupation des lits est de 100.0% (4...   Neurology  critique
# 1  Ratio médecin/patients de 1:52, ce qui est inf...     Surgery  critique
# 2  Ratio médecin/patients de 1:52, ce qui est inf...     Surgery  critique

# %% [markdown]
# ### **Recommendations**

# %%
alertes
# Out:
# [{'titre': "Taux d'occupation critique en Neurology",
#   'message': "Le taux d'occupation des lits est de 100.0% (40 patients pour 40 lits).",
#   'departement': 'Neurology',
#   'type': 'critique'},
#  {'titre': 'Manque de médecins en Surgery',
#   'message': 'Ratio médecin/patients de 1:52, ce qui est inférieur aux recommandations.',
#   'departement': 'Surgery',
#   'type': 'critique'},
#  {'titre': 'Manque de médecins en Surgery',
#   'message': 'Ratio médecin/patients de 1:52, ce qui est inférieur aux recommandations.',
#   'departement': 'Surgery',
#   'type': 'critique'}]

# %%
# Recommendations

recommendations = []

# %%
for a in alertes :
  if "occupation" in a['titre'].lower():
    print(a)
# Out:
# {'titre': "Taux d'occupation critique en Neurology", 'message': "Le taux d'occupation des lits est de 100.0% (40 patients pour 40 lits).", 'departement': 'Neurology', 'type': 'critique'}

# %%
# Recommendations basées sur les alertes

alertes_occupation = [a for a in alertes if "occupation" in a['titre'].lower()]
alertes_occupation
if alertes_occupation:
  depts_concernes = [a['departement'] for a in alertes_occupation]
  recommendations.append({
    'titre': "Optimisation de la capacité d'accueil",
    'message': f"Envisager d'augmenter la capacité en lits dans les départements suivants : {', '.join(depts_concernes)}. Alternativement, mettre en place un système de transfert vers d'autres établissements pour les cas non urgents."
    })
  print(recommendations)
# Out:
# [{'titre': "Optimisation de la capacité d'accueil", 'message': "Envisager d'augmenter la capacité en lits dans les départements suivants : Neurology. Alternativement, mettre en place un système de transfert vers d'autres établissements pour les cas non urgents."}]

# %%
alertes_retablissement = [a for a in alertes if "rétablissement" in a['titre'].lower()]

alertes_retablissement
# Out:
# []

# %%
# Recommandations pour l'amélioration des taux de rétablissement

alertes_retablissement = [a for a in alertes if "rétablissement" in a['titre'].lower()]
if alertes_retablissement:
  depts_concernes = [a['departement'] for a in alertes_retablissement]
  recommendations.append({
  'titre': "Amélioration des taux de rétablissement",
  'message': f"Analyser les protocoles de traitement dans les départements suivants : {', '.join(depts_concernes)}. Envisager une révision des protocoles de soins et une formation supplémentaire du personnel."
  })
  # print(recommendations)

# %%
# Recommandations pour l'optimisation du personnel

alertes_personnel = [a for a in alertes if "médecins" in a['titre'].lower() or "personnel" in a['titre'].lower()]
if alertes_personnel:
  depts_concernes = [a['departement'] for a in alertes_personnel]
  recommendations.append({
      'titre': "Optimisation des ressources humaines",
      'message': f"Recruter du personnel supplémentaire ou réaffecter temporairement du personnel vers les départements suivants : {', '.join(depts_concernes)}. Envisager également des heures supplémentaires pour le personnel existant."
      })
  # print(recommendations)

# %%
# Recommandations financières

alertes_financieres = [a for a in alertes if "financier" in a['titre'].lower() or "déficit" in a['titre'].lower()]
if alertes_financieres:
  recommendations.append({
      'titre': "Optimisation financière",
      'message': "Revoir la structure des coûts et identifier les postes de dépenses à optimiser. Envisager une révision des tarifs pour certains services spécialisés."
      })

# %%
# Recommandations générales basées sur les données

# Recommandation sur la durée d'hospitalisation
duree_moyenne = patient_data["stayDuration"].mean()
if duree_moyenne > 10:  # Si la durée moyenne est supérieure à 10 jours
  recommendations.append({
  'titre': "Réduction de la durée d'hospitalisation",
  'message': f"La durée moyenne d'hospitalisation est de {duree_moyenne:.1f} jours. Mettre en place des protocoles de sortie anticipée pour les patients stables et développer les soins ambulatoires."
        })

# %%
dept_counts = patient_data['department'].value_counts()


print(f"{dept_counts.idxmax()} : {dept_counts.max()}") # Le departement qui s'affiche le plus
print("-----------------")
print(f"{dept_counts.idxmin()} : {dept_counts.min()} ") # Le departement qui s'affiche le moins
print("-----------------")
print(f"Vérifier si {dept_counts.idxmax()} a 3 fois plus de patients que {dept_counts.idxmin()} : {dept_counts.max() > 3 * dept_counts.min()}")
# Out:
# Pediatrics : 177
# -----------------
# Surgery : 156
# -----------------
# Vérifier si Pediatrics a 3 fois plus de patients que Surgery : False

# %%
# Recommandation sur l'équilibre des départements

dept_counts = patient_data['department'].value_counts()
if len(dept_counts) > 1:  # S'assurer qu'il y a au moins deux départements
  max_dept = dept_counts.idxmax()
  min_dept = dept_counts.idxmin()
  if dept_counts.max() > 3 * dept_counts.min():  # Si un département a 3 fois plus de patients qu'un autre
    recommendations.append({
    'titre': "Rééquilibrage des ressources entre départements",
    'message': f"Le département {max_dept} traite significativement plus de patients que le département {min_dept}. Envisager une redistribution des ressources et du personnel."
    })

# %%
recommendations
# Out:
# [{'titre': "Optimisation de la capacité d'accueil",
#   'message': "Envisager d'augmenter la capacité en lits dans les départements suivants : Neurology. Alternativement, mettre en place un système de transfert vers d'autres établissements pour les cas non urgents."},
#  {'titre': 'Optimisation des ressources humaines',
#   'message': 'Recruter du personnel supplémentaire ou réaffecter temporairement du personnel vers les départements suivants : Surgery, Surgery. Envisager également des heures supplémentaires pour le personnel existant.'},
#  {'titre': "Réduction de la durée d'hospitalisation",
#   'message': "La durée moyenne d'hospitalisation est de 13.7 jours. Mettre en place des protocoles de sortie anticipée pour les patients stables et développer les soins ambulatoires."}]

# %%
reco = pd.DataFrame(recommendations)
reco
# Out:
#                                      titre  \
# 0    Optimisation de la capacité d'accueil
# 1     Optimisation des ressources humaines
# 2  Réduction de la durée d'hospitalisation
#
#                                              message
# 0  Envisager d'augmenter la capacité en lits dans...
# 1  Recruter du personnel supplémentaire ou réaffe...
# 2  La durée moyenne d'hospitalisation est de 13.7...

# %% [markdown]
# ## **Résumé**

# %%
# Resume

resume = []

# %%
# Statistiques générales

total_patients = len(patient_data)
patients_hospitalises = len(patient_data[patient_data['isAdmitted']])
taux_occupation_moyen = department_data['bedUtilization'].mean()
taux_retablissement_moyen = department_data['recoveryRate'].mean()

resume.append({
    'titre': "Vue d'ensemble",
    'message': f"L'établissement a traité {total_patients} patients, dont {patients_hospitalises} sont actuellement hospitalisés. Le taux d'occupation moyen est de {taux_occupation_moyen*100:.1f}% et le taux de rétablissement moyen est de {taux_retablissement_moyen*100:.1f}%."
    })
# resume

# %%
# Département le plus performant

if not department_data.empty:
  dept_performance = department_data.copy()
  dept_performance['score'] = dept_performance['recoveryRate'] * 0.6 + (1 - dept_performance['bedUtilization']) * 0.4
  meilleur_dept = dept_performance.loc[dept_performance['score'].idxmax()]

  resume.append({
      'titre': "Département le plus performant",
      'message': f"Le département de {meilleur_dept['department']} présente les meilleurs indicateurs avec un taux de rétablissement de {meilleur_dept['recoveryRate']*100:.1f}% et un taux d'occupation équilibré de {meilleur_dept['bedUtilization']*100:.1f}%."
      })

# %% [markdown]
# - dept_performance['recoveryRate'] * 0.6
#
# → on donne un poids de 60% au taux de guérison (recoveryRate).
#
# - (1 - dept_performance['bedUtilization']) * 0.4
#
# → on donne un poids de 40% à l'inverse du taux d’occupation des lits :
#
# - Plus un lit est libre (i.e. faible taux d’occupation), plus le score augmente ici.

# %%
dept_performance['score']
# Out:
# 0    0.656
# 1    0.504
# 2    0.732
# 3    0.546
# 4    0.496
# 5    0.634
# Name: score, dtype: float64

# %%
resume[1]
# Out:
# {'titre': 'Département le plus performant',
#  'message': "Le département de Oncology présente les meilleurs indicateurs avec un taux de rétablissement de 84.0% et un taux d'occupation équilibré de 43.0%."}

# %%
# Tendances financières

if len(metrics_data) >= 30:
  dernier_mois = metrics_data.sort_values('date').tail(30)
  revenus_total = dernier_mois['revenue'].sum()
  depenses_total = dernier_mois['expenses'].sum()
  profit = revenus_total - depenses_total

  resume.append({
    'titre': "Situation financière",
    'message': f"Sur les 30 derniers jours, l'établissement a généré {revenus_total} de revenus pour {depenses_total} de dépenses, résultant en {'un profit' if profit >= 0 else 'une perte'} de {abs(profit)}."
    })

# %%
abs(profit)
# Out:
# np.int64(483709)

# %%
resume[2]
# Out:
# {'titre': 'Situation financière',
#  'message': "Sur les 30 derniers jours, l'établissement a généré 2892363 de revenus pour 2408654 de dépenses, résultant en un profit de 483709."}

# %%
# Résumé des alertes

if alertes:
  alertes_critiques = len([a for a in alertes if a['type'] == 'critique'])
  alertes_avertissement = len([a for a in alertes if a['type'] == 'avertissement'])

  resume.append({
    'titre': "Points d'attention",
    'message': f"Le système a identifié {alertes_critiques} alertes critiques et {alertes_avertissement} avertissements qui nécessitent une attention particulière."
    })

# %%
resume[3]
# Out:
# {'titre': "Points d'attention",
#  'message': 'Le système a identifié 3 alertes critiques et 0 avertissements qui nécessitent une attention particulière.'}

# %% [markdown]
# # **Tableau Compact : Analysis**

# %%
if len(metrics_data) > 0:
        fig = px.line(metrics_data, x='date', y=['newAdmissions', 'discharges'],
                     title="Admissions_discharges",
                     labels={'value': "count", 'date': "date", 'variable': "metric"},
                     color_discrete_map={'nouvellesAdmissions': "#3498DB", 'sorties': "#1F618D"})
        fig.update_layout(
            height=250,
            legend_title_text='',
            legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1),
            plot_bgcolor= "#141E2E",
            paper_bgcolor= "#141E2E",
            font=dict(color="#E0E0E0"),
            #xaxis=dict(gridcolor= "#E0E0E0"),
            #yaxis=dict(gridcolor=current_theme["border_color"]),
            margin=dict(l=10, r=10, t=40, b=10)
        )
        fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ff8d3430-21cc-4285-a148-84911305dbd0" class="plotly-graph-div" style="height:250px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff8d3430-21cc-4285-a148-84911305dbd0")) {                    Plotly.newPlot(                        "ff8d3430-21cc-4285-a148-84911305dbd0",                        [{"hovertemplate":"metric=newAdmissions\u003cbr\u003edate=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"newAdmissions","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"newAdmissions","orientation":"v","showlegend":true,"x":["2025-04-22T00:00:00","2025-04-23T00:00:00","2025-04-24T00:00:00","2025-04-25T00:00:00","2025-04-26T00:00:00","2025-04-27T00:00:00","2025-04-28T00:00:00","2025-04-29T00:00:00","2025-04-30T00:00:00","2025-05-01T00:00:00","2025-05-02T00:00:00","2025-05-03T00:00:00","2025-05-04T00:00:00","2025-05-05T00:00:00","2025-05-06T00:00:00","2025-05-07T00:00:00","2025-05-08T00:00:00","2025-05-09T00:00:00","2025-05-10T00:00:00","2025-05-11T00:00:00","2025-05-12T00:00:00","2025-05-13T00:00:00","2025-05-14T00:00:00","2025-05-15T00:00:00","2025-05-16T00:00:00","2025-05-17T00:00:00","2025-05-18T00:00:00","2025-05-19T00:00:00","2025-05-20T00:00:00","2025-05-21T00:00:00","2025-05-22T00:00:00","2025-05-23T00:00:00","2025-05-24T00:00:00","2025-05-25T00:00:00","2025-05-26T00:00:00","2025-05-27T00:00:00","2025-05-28T00:00:00","2025-05-29T00:00:00","2025-05-30T00:00:00","2025-05-31T00:00:00","2025-06-01T00:00:00","2025-06-02T00:00:00","2025-06-03T00:00:00","2025-06-04T00:00:00","2025-06-05T00:00:00","2025-06-06T00:00:00","2025-06-07T00:00:00","2025-06-08T00:00:00","2025-06-09T00:00:00","2025-06-10T00:00:00","2025-06-11T00:00:00","2025-06-12T00:00:00","2025-06-13T00:00:00","2025-06-14T00:00:00","2025-06-15T00:00:00","2025-06-16T00:00:00","2025-06-17T00:00:00","2025-06-18T00:00:00","2025-06-19T00:00:00","2025-06-20T00:00:00","2025-06-21T00:00:00","2025-06-22T00:00:00","2025-06-23T00:00:00","2025-06-24T00:00:00","2025-06-25T00:00:00","2025-06-26T00:00:00","2025-06-27T00:00:00","2025-06-28T00:00:00","2025-06-29T00:00:00","2025-06-30T00:00:00","2025-07-01T00:00:00","2025-07-02T00:00:00","2025-07-03T00:00:00","2025-07-04T00:00:00","2025-07-05T00:00:00","2025-07-06T00:00:00","2025-07-07T00:00:00","2025-07-08T00:00:00","2025-07-09T00:00:00","2025-07-10T00:00:00","2025-07-11T00:00:00","2025-07-12T00:00:00","2025-07-13T00:00:00","2025-07-14T00:00:00","2025-07-15T00:00:00","2025-07-16T00:00:00","2025-07-17T00:00:00","2025-07-18T00:00:00","2025-07-19T00:00:00","2025-07-20T00:00:00"],"xaxis":"x","y":[22,23,6,17,15,14,13,19,20,15,14,6,13,19,5,16,25,21,8,18,8,24,10,23,17,25,8,24,21,5,16,8,23,15,10,17,21,23,14,23,10,20,8,5,21,10,23,12,10,8,16,17,19,9,18,23,12,15,5,19,14,7,6,21,25,16,14,17,6,19,12,9,14,16,18,5,14,11,23,8,15,10,16,9,20,25,22,7,11,12],"yaxis":"y","type":"scatter"},{"hovertemplate":"metric=discharges\u003cbr\u003edate=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"discharges","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"discharges","orientation":"v","showlegend":true,"x":["2025-04-22T00:00:00","2025-04-23T00:00:00","2025-04-24T00:00:00","2025-04-25T00:00:00","2025-04-26T00:00:00","2025-04-27T00:00:00","2025-04-28T00:00:00","2025-04-29T00:00:00","2025-04-30T00:00:00","2025-05-01T00:00:00","2025-05-02T00:00:00","2025-05-03T00:00:00","2025-05-04T00:00:00","2025-05-05T00:00:00","2025-05-06T00:00:00","2025-05-07T00:00:00","2025-05-08T00:00:00","2025-05-09T00:00:00","2025-05-10T00:00:00","2025-05-11T00:00:00","2025-05-12T00:00:00","2025-05-13T00:00:00","2025-05-14T00:00:00","2025-05-15T00:00:00","2025-05-16T00:00:00","20 ...

# %%
if not department_data.empty:
        fig = px.bar(department_data, x='department', y='bedUtilization',
                    title="Bed_utilization",
                    labels={'bedUtilization': "Bed_utilization_label", 'department': "department_label"},
                    #color='departement  'departement': t("department_label")},
                    color='department',
                    color_discrete_map={dept: color for dept, color in zip(department_data['department'], ["#3498DB", "#2980B9", "#1F618D", "#2C3E50", "#5DADE2", "#85C1E9", "#7F8C8D"])})
        fig.update_layout(
            height=250,
            coloraxis_showscale=False,
            plot_bgcolor="#141E2E",
            paper_bgcolor="#141E2E",
            font=dict(color="#E0E0E0"),
            #xaxis=dict(gridcolor=current_theme["border_color"]),
            #yaxis=dict(gridcolor=current_theme["border_color"]),
            showlegend=False,
            margin=dict(l=10, r=10, t=40, b=10)
        )
        fig.update_yaxes(range=[0, 1], tickformat='.0%')
        fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="60172d81-f760-4b3c-a453-b28774238cd3" class="plotly-graph-div" style="height:250px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60172d81-f760-4b3c-a453-b28774238cd3")) {                    Plotly.newPlot(                        "60172d81-f760-4b3c-a453-b28774238cd3",                        [{"alignmentgroup":"True","hovertemplate":"department_label=%{x}\u003cbr\u003eBed_utilization_label=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cardiology","marker":{"color":"#3498DB","pattern":{"shape":""}},"name":"Cardiology","offsetgroup":"Cardiology","orientation":"v","showlegend":true,"textposition":"auto","x":["Cardiology"],"xaxis":"x","y":[0.56],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"department_label=%{x}\u003cbr\u003eBed_utilization_label=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Neurology","marker":{"color":"#2980B9","pattern":{"shape":""}},"name":"Neurology","offsetgroup":"Neurology","orientation":"v","showlegend":true,"textposition":"auto","x":["Neurology"],"xaxis":"x","y":[1.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"department_label=%{x}\u003cbr\u003eBed_utilization_label=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oncology","marker":{"color":"#1F618D","pattern":{"shape":""}},"name":"Oncology","offsetgroup":"Oncology","orientation":"v","showlegend":true,"textposition":"auto","x":["Oncology"],"xaxis":"x","y":[0.43],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"department_label=%{x}\u003cbr\u003eBed_utilization_label=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pediatrics","marker":{"color":"#2C3E50","pattern":{"shape":""}},"name":"Pediatrics","offsetgroup":"Pediatrics","orientation":"v","showlegend":true,"textposition":"auto","x":["Pediatrics"],"xaxis":"x","y":[0.8200000000000001],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"department_label=%{x}\u003cbr\u003eBed_utilization_label=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Emergency","marker":{"color":"#5DADE2","pattern":{"shape":""}},"name":"Emergency","offsetgroup":"Emergency","orientation":"v","showlegend":true,"textposition":"auto","x":["Emergency"],"xaxis":"x","y":[0.9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"department_label=%{x}\u003cbr\u003eBed_utilization_label=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Surgery","marker":{"color":"#85C1E9","pattern":{"shape":""}},"name":"Surgery","offsetgroup":"Surgery","orientation":"v","showlegend":true,"textposition":"auto","x":["Surgery"],"xaxis":"x","y":[0.66],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333, ...

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Two subplots to compare Recovery Rate and BedUtilization

if not department_data.empty:
  fig = make_subplots(rows=1, cols=2,
                      subplot_titles=("Recovery Rate", "Bed Utilization"))

  # Define the grayscale color sequence
  grayscale_colors = ["#E74C3C", "#C0392B", "#D35400", "#E67E22", "#F39C12", "#922B21", "#7F8C8D"]

  # Add Recovery Rate bar chart
  fig.add_trace(
      go.Bar(x=department_data['department'], y=department_data['recoveryRate'], name='Recovery Rate',
             marker_color=grayscale_colors[:len(department_data['department'])]), # Assign colors
      row=1, col=1
  )

  # Add Bed Utilization bar chart
  fig.add_trace(
      go.Bar(x=department_data['department'], y=department_data['bedUtilization'], name='Bed Utilization',
             marker_color=grayscale_colors[:len(department_data['department'])]), # Assign colors
      row=1, col=2
  )

  # Update layout
  fig.update_layout(
      title_text="Department Performance: Recovery Rate vs. Bed Utilization",
      showlegend=True,
      paper_bgcolor='black',
      plot_bgcolor='black',
      font=dict(color='white')
  )

  fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8542c2d2-c07f-4ba3-8667-a988e99b2fa9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8542c2d2-c07f-4ba3-8667-a988e99b2fa9")) {                    Plotly.newPlot(                        "8542c2d2-c07f-4ba3-8667-a988e99b2fa9",                        [{"marker":{"color":["#E74C3C","#C0392B","#D35400","#E67E22","#F39C12","#922B21"]},"name":"Recovery Rate","x":["Cardiology","Neurology","Oncology","Pediatrics","Emergency","Surgery"],"y":[0.8,0.84,0.84,0.79,0.76,0.8300000000000001],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":["#E74C3C","#C0392B","#D35400","#E67E22","#F39C12","#922B21"]},"name":"Bed Utilization","x":["Cardiology","Neurology","Oncology","Pediatrics","Emergency","Surgery"],"y":[0.56,1.0,0.43,0.8200000000000001,0.9,0.66],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","w ...

# %%
if not patient_data.empty:
  dept_counts = patient_data['department'].value_counts().reset_index()
  dept_counts.columns = [("department_label"), "count"]

  # Créer une carte de couleurs pour les départements
  dept_color_map = {dept: color for dept, color in zip(dept_counts["department_label"], ["#E74C3C", "#C0392B", "#D35400", "#E67E22", "#F39C12", "#922B21", "#7F8C8D"])}

  fig = px.pie(dept_counts, values="count", names="department_label",
    title="patient_distribution",
    color="department_label",
    color_discrete_map=dept_color_map)
  fig.update_traces(textposition='inside', textinfo='percent+label', textfont=dict(color='#000000'))
  fig.update_layout(
    legend=dict(orientation="h", yanchor="bottom", y=-0.1, xanchor="center", x=0.5),
    font=dict(color="#F0F0F0"),
    paper_bgcolor="#0E0808",
    plot_bgcolor="#0E0808"
    )

  fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8f3112d3-03be-4abf-9548-2bcb9afe3ac8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f3112d3-03be-4abf-9548-2bcb9afe3ac8")) {                    Plotly.newPlot(                        "8f3112d3-03be-4abf-9548-2bcb9afe3ac8",                        [{"customdata":[["Pediatrics"],["Emergency"],["Oncology"],["Neurology"],["Cardiology"],["Surgery"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"department_label=%{customdata[0]}\u003cbr\u003ecount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Pediatrics","Emergency","Oncology","Neurology","Cardiology","Surgery"],"legendgroup":"","marker":{"colors":["#E74C3C","#C0392B","#D35400","#E67E22","#F39C12","#922B21"]},"name":"","showlegend":true,"values":[177,170,168,168,161,156],"type":"pie","textfont":{"color":"#000000"},"textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{ ...

# %% [markdown]
# ##### **Date Format**

# %%
min_date = metrics_data['date'].min().date()
max_date = metrics_data['date'].max().date()
plage_date = (min_date, max_date)

# %%
if len(plage_date) == 2:
    date_debut, date_fin = plage_date
    # Convertir en datetime pour une comparaison correcte
    date_debut_dt = pd.Timestamp(date_debut)
    date_fin_dt = pd.Timestamp(date_fin)
    quotidien_filtre = metrics_data[(metrics_data['date'] >= date_debut_dt) & (metrics_data['date'] <= date_fin_dt)]
else:
    quotidien_filtre = metrics_data
    # Par défaut à la plage complète si plage_date n'est pas correctement définie
    date_debut = min_date
    date_fin = max_date

# %%
# Display informations

print(f"Date de début : {date_debut}")
print(f"Date de fin : {date_fin}")
print(f"Quantité de données : {len(quotidien_filtre)}")
# Out:
# Date de début : 2025-04-22
# Date de fin : 2025-07-20
# Quantité de données : 90

# %%
# Test Plage date using timedelta between the choosen date and the moment the program is executed

choosen_date = input("Enter the date - yyyy/mm/dd : ")

# Convert choosen date
choosen_date = pd.to_datetime(choosen_date)
print(f"Choosen date : {choosen_date}")
print(f"Moment de l'exécution du programme : {pd.Timestamp.now()}")
print(choosen_date in plage_date)
if choosen_date in plage_date :
  if len(plage_date) == 2:
      date_debut, date_fin = plage_date

  print(plage_date)
  print(f"La différence entre la date de debut et de fin {date_fin - date_debut}")
# Out:
# Enter the date - yyyy/mm/dd : 2025-02-01
# Choosen date : 2025-02-01 00:00:00
# Moment de l'exécution du programme : 2025-07-21 14:46:03.441006
# False

# %%
# Test 2025-04-22

# Test Plage date using timedelta between the choosen date and the moment the program is executed

choosen_date = input("Enter the date - yyyy/mm/dd : ")
print("============================")

# Convert choosen date
choosen_date = pd.to_datetime(choosen_date)
current_date = pd.Timestamp.now()
choosen_date, current_date = plage_date

print(f"Choosen date : {choosen_date}")
print(f"Current date : {pd.Timestamp.now()}")

print(f"Verify if choosen_date in Date column : {choosen_date in quotidien_filtre['date']}")
print(current_date - choosen_date)
# Out:
# Enter the date - yyyy/mm/dd : 2025-04-22
# ============================
# Choosen date : 2025-04-22
# Current date : 2025-07-21 14:46:13.980661
# Verify if choosen_date in Date column : False
# 89 days, 0:00:00

# %%
# Iterate through the date column and calculate the difference between the previous date and the following one in a new column
for index, row in quotidien_filtre.iterrows():
    if index > 0:
        previous_date = quotidien_filtre.loc[index - 1, 'date']
        quotidien_filtre.loc[index, 'date_diff'] = row['date'] - previous_date

quotidien_filtre["date_diff"] = pd.to_timedelta(quotidien_filtre["date_diff"])

# %%
# quotidien_filtre
# Out:
#          date  newAdmissions  discharges  emergencyVisits  surgeries  revenue  \
# 0  2025-04-22             22           8               60         13   120038
# 1  2025-04-23             23           8               34         13   106975
# 2  2025-04-24              6           9               58          9   134386
# 3  2025-04-25             17           5               38         12   112336
# 4  2025-04-26             15          17               29         15    70154
# ..        ...            ...         ...              ...        ...      ...
# 85 2025-07-16             25          10               21          3    59076
# 86 2025-07-17             22           6               36          6   107755
# 87 2025-07-18              7          12               52          8   117072
# 88 2025-07-19             11          12               26          7    92570
# 89 2025-07-20             12          18               44         12    95661
#
#     expenses date_diff
# 0      77681       NaT
# 1      65743    1 days
# 2      68412    1 days
# 3      54216    1 days
# 4     112666    1 days
# ..       ...       ...
# 85     65621    1 days
# 86     49625    1 days
# 87     51181    1 days
# 88     69067    1 days
# 89     82032    1 days
#
# [90 rows x 8 columns]

# %%
# Revenue vs Charges

fig = px.line(quotidien_filtre, x='date', y=['revenue', 'expenses'],
  title="Revenue & Expenses",
  labels={'value': "amount", 'date': "date", 'variable': "metric"},
  color_discrete_map={'revenus': "#27AE60", 'depenses': "#C0392B"})

# Ajouter la zone de profit

quotidien_filtre['profit'] = quotidien_filtre['revenue'] - quotidien_filtre['expenses']
fig.add_trace(go.Scatter(
x=quotidien_filtre['date'],
y=quotidien_filtre['profit'],
fill='tozeroy',
mode='none',
name="profit",
fillcolor=f'rgba({int("#27AE60"[1:3], 16)}, {int("#C0392B"[3:5], 16)}, {int("#27AE60"[5:7], 16)}, 0.2)'
        ))

fig.update_layout(
            legend_title_text='',
            legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1),
            plot_bgcolor="#162727",
            paper_bgcolor="#162727",
            font=dict(color="#E0E0E0"),
            xaxis=dict(gridcolor="#1E3535"),
            yaxis=dict(gridcolor="#1E3535")
        )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="432f1901-59f1-4283-89c2-490c5e4816af" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("432f1901-59f1-4283-89c2-490c5e4816af")) {                    Plotly.newPlot(                        "432f1901-59f1-4283-89c2-490c5e4816af",                        [{"hovertemplate":"metric=revenue\u003cbr\u003edate=%{x}\u003cbr\u003eamount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"revenue","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"revenue","orientation":"v","showlegend":true,"x":["2025-04-22T00:00:00","2025-04-23T00:00:00","2025-04-24T00:00:00","2025-04-25T00:00:00","2025-04-26T00:00:00","2025-04-27T00:00:00","2025-04-28T00:00:00","2025-04-29T00:00:00","2025-04-30T00:00:00","2025-05-01T00:00:00","2025-05-02T00:00:00","2025-05-03T00:00:00","2025-05-04T00:00:00","2025-05-05T00:00:00","2025-05-06T00:00:00","2025-05-07T00:00:00","2025-05-08T00:00:00","2025-05-09T00:00:00","2025-05-10T00:00:00","2025-05-11T00:00:00","2025-05-12T00:00:00","2025-05-13T00:00:00","2025-05-14T00:00:00","2025-05-15T00:00:00","2025-05-16T00:00:00","2025-05-17T00:00:00","2025-05-18T00:00:00","2025-05-19T00:00:00","2025-05-20T00:00:00","2025-05-21T00:00:00","2025-05-22T00:00:00","2025-05-23T00:00:00","2025-05-24T00:00:00","2025-05-25T00:00:00","2025-05-26T00:00:00","2025-05-27T00:00:00","2025-05-28T00:00:00","2025-05-29T00:00:00","2025-05-30T00:00:00","2025-05-31T00:00:00","2025-06-01T00:00:00","2025-06-02T00:00:00","2025-06-03T00:00:00","2025-06-04T00:00:00","2025-06-05T00:00:00","2025-06-06T00:00:00","2025-06-07T00:00:00","2025-06-08T00:00:00","2025-06-09T00:00:00","2025-06-10T00:00:00","2025-06-11T00:00:00","2025-06-12T00:00:00","2025-06-13T00:00:00","2025-06-14T00:00:00","2025-06-15T00:00:00","2025-06-16T00:00:00","2025-06-17T00:00:00","2025-06-18T00:00:00","2025-06-19T00:00:00","2025-06-20T00:00:00","2025-06-21T00:00:00","2025-06-22T00:00:00","2025-06-23T00:00:00","2025-06-24T00:00:00","2025-06-25T00:00:00","2025-06-26T00:00:00","2025-06-27T00:00:00","2025-06-28T00:00:00","2025-06-29T00:00:00","2025-06-30T00:00:00","2025-07-01T00:00:00","2025-07-02T00:00:00","2025-07-03T00:00:00","2025-07-04T00:00:00","2025-07-05T00:00:00","2025-07-06T00:00:00","2025-07-07T00:00:00","2025-07-08T00:00:00","2025-07-09T00:00:00","2025-07-10T00:00:00","2025-07-11T00:00:00","2025-07-12T00:00:00","2025-07-13T00:00:00","2025-07-14T00:00:00","2025-07-15T00:00:00","2025-07-16T00:00:00","2025-07-17T00:00:00","2025-07-18T00:00:00","2025-07-19T00:00:00","2025-07-20T00:00:00"],"xaxis":"x","y":[120038,106975,134386,112336,70154,54161,118853,91066,119196,86446,117721,88856,53192,72284,96973,87513,105405,119397,101226,129411,148729,60213,111561,76874,78778,97800,124106,82228,57349,51847,105368,87101,119590,132379,131214,59385,91994,123065,145672,103615,96536,94129,103316,97491,83634,61254,114485,148818,146702,97586,89187,146474,139097,139894,126584,139053,147392,136147,83394,64752,146136,121923,114119,111421,143143,52641,51839,55292,57120,93312,82147,89199,97710,63298,142497,112379,94149,97062,61420,129222,130590,98782,108202,78430,88196,59076,107755,117072,92570,95661],"yaxis":"y","type":"scatter"},{"hovertemplate":"metric=expenses\u003cbr\u003edate=%{x}\u003cbr\u003eamount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"expenses","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"expenses","orientation":"v","showlegend":true,"x":["2025-04-22T00:00:00","2025-04-23T00:00:00","2025-04-24T00:00:00","2025-04-25T00:00:00","2025-04-26T00:00:00","2025-04-27T00:00:00","2025-04-28T00:00:00","2025-04-29T00:00:00","2025-04-30T00:00:00","2025-05-01T00:00:00","2025-05-02T00:00:00 ...

# %%
# Revenus et coûts par département

if not department_data.empty:
  fig = go.Figure()

fig.add_trace(go.Bar(
  x=department_data['department'],
  y=department_data['totalRevenue'],
  name="revenue",
  marker_color="#4CAF50"
  ))

fig.add_trace(go.Bar(
  x=department_data['department'],
  y=department_data['operatingCost'],
  name="operating_cost",
  marker_color="#B71C1C"
  ))

fig.update_layout(
  title="department_revenue_cost",
  barmode='group',
  xaxis_title="department_label",
  yaxis_title="amount",
  legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1),
  plot_bgcolor="#1E1E1E",
  paper_bgcolor="#1E1E1E",
  font=dict(color="#E0E0E0"),
  xaxis=dict(gridcolor="#2A2A2A"),
  yaxis=dict(gridcolor="#2A2A2A")
            )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="be4f2984-8159-4f80-9dd0-0862c2281869" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be4f2984-8159-4f80-9dd0-0862c2281869")) {                    Plotly.newPlot(                        "be4f2984-8159-4f80-9dd0-0862c2281869",                        [{"marker":{"color":"#4CAF50"},"name":"revenue","x":["Cardiology","Neurology","Oncology","Pediatrics","Emergency","Surgery"],"y":[7985903,9111593,9909357,7541597,9767089,10473640],"type":"bar"},{"marker":{"color":"#B71C1C"},"name":"operating_cost","x":["Cardiology","Neurology","Oncology","Pediatrics","Emergency","Surgery"],"y":[2798682,2741313,3789201,3059114,2739548,2575019],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlin ...

# %%
chart_colors =  ["#D4AF37", "#C0C0C0", "#9D8221", "#B8860B", "#E6BE8A", "#DAA520", "#A8A8A8"]

# Section du personnel

# Distribution du personnel par rôle
if not staff_data.empty:
  role_counts = staff_data['role'].value_counts().reset_index()
  role_counts.columns = ["role", "count"]

# Créer une carte de couleurs pour les rôles
  role_colors = {
  "doctor": chart_colors[0],
  "nurse": chart_colors[1],
  "technician": chart_colors[2],
  "administrative": chart_colors[3],
  "support": chart_colors[4]
            }

fig = px.bar(role_counts, x="role", y="count",
  title="staff_distribution",
    color="role",
    color_discrete_map=role_colors)

fig.update_layout(
  showlegend=False,
  plot_bgcolor="#1A1010",
  paper_bgcolor="#1A1010",
  font=dict(color="#F0F0F0"),
  xaxis=dict(gridcolor="#2A1515"),
  yaxis=dict(gridcolor="#2A1515")
  )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="13638abd-36ca-4a40-9847-4be16a4d9db5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("13638abd-36ca-4a40-9847-4be16a4d9db5")) {                    Plotly.newPlot(                        "13638abd-36ca-4a40-9847-4be16a4d9db5",                        [{"alignmentgroup":"True","hovertemplate":"role=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nurse","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Nurse","offsetgroup":"Nurse","orientation":"v","showlegend":true,"textposition":"auto","x":["Nurse"],"xaxis":"x","y":[44],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"role=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Doctor","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Doctor","offsetgroup":"Doctor","orientation":"v","showlegend":true,"textposition":"auto","x":["Doctor"],"xaxis":"x","y":[43],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"role=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Technician","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Technician","offsetgroup":"Technician","orientation":"v","showlegend":true,"textposition":"auto","x":["Technician"],"xaxis":"x","y":[40],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"role=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Support","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Support","offsetgroup":"Support","orientation":"v","showlegend":true,"textposition":"auto","x":["Support"],"xaxis":"x","y":[38],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"role=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Administrative","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Administrative","offsetgroup":"Administrative","orientation":"v","showlegend":true,"textposition":"auto","x":["Administrative"],"xaxis":"x","y":[34],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contou ...

# %%
# Performance du personnel

if not staff_data.empty:
  performance_data = staff_data.groupby('role')['performanceScore'].mean().reset_index()

fig = px.bar(performance_data, x='role', y='performanceScore',
  title="performance_score",
  labels={'scorePerformance': "performance_score", 'role': "role"},
  color='role',
  color_discrete_map=role_colors)

fig.update_layout(
  showlegend=False,
  plot_bgcolor="#1A1010",
  paper_bgcolor="#1A1010",
  font=dict(color="#F0F0F0"),
  xaxis=dict(gridcolor="#2A1515"),
  yaxis=dict(gridcolor="#2A1515")
  )

fig.update_yaxes(range=[0, 1])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="28babc1a-6ad9-45a0-a5d7-081012238686" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28babc1a-6ad9-45a0-a5d7-081012238686")) {                    Plotly.newPlot(                        "28babc1a-6ad9-45a0-a5d7-081012238686",                        [{"alignmentgroup":"True","hovertemplate":"role=%{x}\u003cbr\u003eperformanceScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Administrative","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Administrative","offsetgroup":"Administrative","orientation":"v","showlegend":true,"textposition":"auto","x":["Administrative"],"xaxis":"x","y":[0.8694117647058823],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"role=%{x}\u003cbr\u003eperformanceScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Doctor","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Doctor","offsetgroup":"Doctor","orientation":"v","showlegend":true,"textposition":"auto","x":["Doctor"],"xaxis":"x","y":[0.8718604651162791],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"role=%{x}\u003cbr\u003eperformanceScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nurse","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Nurse","offsetgroup":"Nurse","orientation":"v","showlegend":true,"textposition":"auto","x":["Nurse"],"xaxis":"x","y":[0.8504545454545455],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"role=%{x}\u003cbr\u003eperformanceScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Support","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Support","offsetgroup":"Support","orientation":"v","showlegend":true,"textposition":"auto","x":["Support"],"xaxis":"x","y":[0.8560526315789474],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"role=%{x}\u003cbr\u003eperformanceScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Technician","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Technician","offsetgroup":"Technician","orientation":"v","showlegend":true,"textposition":"auto","x":["Technician"],"xaxis":"x","y":[0.8397500000000001],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555555555 ...
